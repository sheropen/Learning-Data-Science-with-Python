# %% [markdown]
# ## 机器翻译作业

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 本次作业使用 seq2seq模型完成英文到中文的机器翻译任务，请补充缺失部分的代码

# %%
#导入常用软件包
import torch
import sys
from torch import nn, optim
import random
from torch.nn.functional import softmax
import torch.nn.functional as F
import re
import os

from torchtext.legacy import data
from torchtext.legacy.data import Iterator, BucketIterator
from collections import defaultdict
import string
import dill

from tqdm import tqdm

# %% [markdown]
# ## 1.数据加载
#
# 数据：包含六个文件：
# 1. 训练集：train.seg.en.txt train.seg.zh.txt （11743条）
# 2. 验证集：dev.seg.en.txt dev.seg.zh.txt （2936条）
# 3. 测试集：test.seg.en.txt test.seg.zh.txt （5194条）
#
# 使用torchtext完成数据的加载，主要使用以下三个组件：
#
# 1. Field :主要包含以下数据预处理的配置信息，比如指定分词方法，是否转成小写，起始字符，结束字符，补全字符以及词典等等
#
# 2. Dataset :继承自pytorch的Dataset，用于加载数据，提供了TabularDataset可以指点路径，格式，Field信息就可以方便的完成数据加载。同时torchtext还提供预先构建的常用数据集的Dataset对象，可以直接加载使用，splits方法可以同时加载训练集，验证集和测试集。
#
# 3. Iterator : 主要是数据输出的模型的迭代器，可以支持batch定制
#
# 具体可以参照：https://pytorch.org/text/stable/index.html
# 关于torchtext的安装可以参照：https://github.com/pytorch/text

# %%
class Dataloader:
    def __init__(self, batch_size, device, eval=False):
        raw_data = self.read_data("/content/drive/MyDrive/machine_translation/data/", test=eval)
        ## 训练模式
        if not eval:
            train_data, dev_data = raw_data
            ##定义数据字段
            self.id_field = data.Field(sequential=False, use_vocab=False)
            self.en_field = data.Field(init_token='<sos>', eos_token='<eos>', lower=True, include_lengths=True)
            self.zh_field = data.Field(init_token='<sos>', eos_token='<eos>', lower=True)
            self.fields = [("id", self.id_field), ("en", self.en_field), ("zh", self.zh_field)]

            ##构建数据集
            train_dataset = data.Dataset([data.Example.fromlist([idx, item[0], item[1]], self.fields) for idx, item in enumerate(train_data)], self.fields)
            dev_dataset =  data.Dataset([data.Example.fromlist([idx, item[0], item[1]], self.fields) for idx, item in enumerate(dev_data)], self.fields)
            
            ##构建数据迭代器
            self.train_iterator= BucketIterator(train_dataset, batch_size=batch_size, device=device, sort_key=lambda x: len(x.en), sort_within_batch=True)
            self.dev_iterator= BucketIterator(dev_dataset, batch_size=batch_size, device=device, sort_key=lambda x: len(x.en), sort_within_batch=True)
            
            ##构建词典
            self.en_field.build_vocab(train_dataset, min_freq=2)
            self.zh_field.build_vocab(train_dataset, min_freq=2)
            
            ##存储字段
            dill.dump(self.en_field, open("/content/drive/MyDrive/machine_translation/model/EN.Field", "wb"))
            dill.dump(self.zh_field, open("/content/drive/MyDrive/machine_translation/model/ZH.Field", "wb"))

            print("en vocab size:", len(self.en_field.vocab.itos),"zh vocab size:", len(self.zh_field.vocab.itos))
        
        ## 测试模式  
        else:
            test_data = raw_data[-1]
            ##加载存储的字段
            self.id_field = data.Field(sequential=False, use_vocab=False)
            self.en_field = dill.load(open("/content/drive/MyDrive/machine_translation/model/EN.Field", "rb"))
            self.zh_field = dill.load(open("/content/drive/MyDrive/machine_translation/model/ZH.Field", "rb"))
            self.fields = [("id", self.id_field), ("en", self.en_field), ("zh", self.zh_field)]
            
            ##构建测试集 & 迭代器
            test_data = data.Dataset([data.Example.fromlist([idx, item[0], item[1]], self.fields) for idx, item in enumerate(test_data)], self.fields)
            self.test_iterator= BucketIterator(test_data, batch_size=batch_size, device=device, train = False, sort_key=lambda x: len(x.en), sort_within_batch = True)   
        
    ##从文件中读取数据
    def read_data(self, path, test=True, lang1='en', lang2 = 'zh'):
        data = []
        types = ['test'] if test else ['train', 'dev']
        # print(types)
        for type in types:
            sub_data = []
            with open(f"{path}/{type}.seg.{lang1}.txt", encoding='utf-8') as f1, open(f"{path}/{type}.seg.{lang2}.txt", encoding='utf-8') as f2:
                for src, trg in zip(f1, f2):
                    if len(src) > MAX_LEN and len(trg) > MAX_LEN:
                        continue
                    sub_data.append((src.strip(), trg.strip()))
            data.append(sub_data)

        return data

# %% [markdown]
# ## 2.模型构建
# 使用seq2seq模型完成机器翻译模型的搭建,可以参考 pytorch tutorials https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html
#
# 这里需要完成的是一个seq2seq+attention的基础模型，有余力的可以进行更多的尝试
# 相关的论文：
# 1. attention:https://arxiv.org/abs/1409.0473
# 2. copy:https://arxiv.org/abs/1603.06393
# 3. coverage:https://arxiv.org/abs/1601.04811

# %% [markdown]
# ### 2.1 Encoder
# 这里为了简化代码，embedding_size和hidden_size使用相同大小，均为传入的hid_dim。RNN模块可以采用双向GRU实现。

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout):
        super().__init__()
        
        ##构建embedding
        self.embedding = nn.Embedding(input_dim, emb_dim)
        
        ##构建rnn模块
        self.rnn = nn.GRU(emb_dim, enc_hid_dim, bidirectional = True)
        
        self.fc = nn.Linear(enc_hid_dim * 2, dec_hid_dim)
        
        ##构建dropout层
        self.dropout = nn.Dropout(dropout)
        
        
    def forward(self, src_info):
        src, src_len = src_info
        
        ## 补充embedding层（+dropout）代码
        embedded = self.dropout(self.embedding(src))
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, src_len.to('cpu'))
        
        ## 补充rnn层代码
        packed_outputs, hidden = self.rnn(packed_embedded)
        outputs, _ = nn.utils.rnn.pad_packed_sequence(packed_outputs) 
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
        
        return outputs, hidden

# %% [markdown]
# ### 2.2 Attention模块
# Attention 机制的 Encoder-Decoder 模型则是要从序列中学习到每一个元素的重要程度，然后按重要程度将元素合并。因此，注意力机制可以看作是 Encoder 和 Decoder 之间的接口，它向 Decoder 提供来自每个 Encoder 隐藏状态的信息。通过该设置，模型能够选择性地关注输入序列的有用部分，从而学习它们之间的“对齐”。这就表明，在 Encoder 将输入的序列元素进行编码时，得到的不在是一个固定的语义编码 C ，而是存在多个语义编码，且不同的语义编码由不同的序列元素以不同的权重参数组合而成。
#
# 在 Attention 机制下，语义编码 C 是各个元素按其重要程度加权求和得到的，即：
#
# $C_i=\sum_{i=1}^{n}{a}_{ij}*{h_i}$
#
# 参数 𝑖 表示时刻， 𝑗 表示序列中的第 𝑗 个元素， 𝑇𝑥 表示序列的长度， 𝑓(⋅) 表示对元素 𝑥𝑗 的编码。𝑎𝑖𝑗 可以看作是一个概率，反映了元素 ℎ𝑗 对 𝐶𝑖 的重要性，可以使用 softmax 来表示：
#
# ${a}_{ij}= \frac{exp(e_{ij})}{\sum_{k=1}^{T_x}exp(e_{ik})}$
#
# where $e_{ij}=a(s_{i-1}, h_j)$

# %% [markdown]
# 请实现Attention模块：
# （也可以不使用单独的Attention模块，在decoder部分的代码中整合Attention机制）

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        self.attn = nn.Linear((enc_hid_dim*2) + dec_hid_dim, dec_hid_dim)
        self.v = nn.Linear(dec_hid_dim, 1, bias=False)


    def forward(self, hidden, encoder_outputs, mask):
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim * 2]
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #将decoder的隐状态重复src_len次
#         print("in attention, hidden shape:", hidden.shape)
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        #hidden = [batch size, src len, dec hid dim]
        #encoder_outputs = [batch size, src len, enc hid dim * 2]
        
        ##请补充计算attention score的代码
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
        attention = self.v(energy).squeeze(2)
        attention.masked_fill(mask == 0, -1e10)
        ##mask掉padding部分，计算softmax
        return F.softmax(attention, dim = 1)

# %% [markdown]
# ### 2.3 Decoder
# 请实现带attention机制的decoder：

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim,emb_dim, enc_hid_dim, dec_hid_dim, dropout, attention):
        super().__init__()
        self.output_dim = output_dim
        self.attention = attention
        ## 继续补充
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = nn.GRU((enc_hid_dim * 2) + emb_dim, dec_hid_dim)
        self.fc_out = nn.Linear((enc_hid_dim * 2) + dec_hid_dim + emb_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, encoder_outputs, mask):
        # input = [batch_size]
        # hidden = [batch_size, dec_hid_dim]
        # encoder_outputs = [src_sent_len, batch_size, enc_hid_dim * 2]
        input = input.unsqueeze(0)
        
        ##embedding层
        embedded = self.dropout(self.embedding(input))
        
        
        ##计算attention score
        a = self.attention(hidden, encoder_outputs,mask).unsqueeze(1)
        
        ##根据attention score计算weighted的context向量
        encoder_outputs = encoder_outputs.permute(1,0,2)
        weighted = torch.bmm(a, encoder_outputs)
        weighted = weighted.permute(1,0,2)
        rnn_input = torch.cat((embedded,weighted), dim=2)
        output, hidden = self.rnn(rnn_input, hidden.unsqueeze(0))
        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))
        
        return prediction, hidden.squeeze(0), a.squeeze(1)

# %% [markdown]
# ## 2.4 Seq2seq模型

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device, pad_idx):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.pad_idx = pad_idx
        self.device = device

    def forward(self, src_info, trg = None, teacher_forcing_ratio = 0.5):
        src, src_len = src_info
        batch_size = src.shape[1]
        max_len = trg.shape[0] if trg is not None else MAX_LEN
        trg_vocab_size = self.decoder.output_dim
        
        ##存储所有decoder输出的结果
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        attn_scores = []
        
        ## encoder
        encoder_outputs, hidden = self.encoder(src_info)

        ##初始化decoder的输入是<sos>token
        input = trg[0, :] if trg is not None else src[0, :]
        
        #mask = [batch size, src len]
        mask = self.create_mask(src)

        
        ## decode过程，每个step decode出一个token 
        for t in range(1, max_len):
            ## 请补全decoder的代码，得到output, hidden, atten_score
            output, hidden, a = self.decoder(input, hidden, encoder_outputs,mask)
            attn_scores.append(a)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = trg[t] if teacher_force else top1
            
            
        return outputs, torch.cat(attn_scores, dim = 1).to(self.device)

    def create_mask(self, src):
        mask = (src != self.pad_idx).permute(1, 0)
        return mask

# %% [markdown]
# ## 3.训练模块代码
# 包括BLEU的计算：BLEU是一种评价机器翻译的指标，NLTK中包含了计算BLEU值的工具。

# %%
## bleu计算
import jieba
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

def calculate_bleu(hypothesis, targets, cut=True, verbose=False):
    bleu_scores = []
    for sent, trg in zip(hypothesis, targets):
        trg = trg.strip().lower().split()
        sent = sent.strip()
        if cut:
            trg = list(jieba.cut(''.join(trg).replace("-", "")))
            sent = list(jieba.cut(''.join(sent).replace("-", "")))
 
        bleu = sentence_bleu([trg], sent, weights=(0.5, 0.5, 0., 0.),smoothing_function = SmoothingFunction().method1)
        if verbose:
            print(f"src:{sent.strip()}\ntrg:{trg}\npredict:{sent}\n{bleu}\n")
        bleu_scores.append(bleu)         
    return sum(bleu_scores) / len(bleu_scores)

# %% [markdown]
# 请补充train_iter的代码:
# （在train函数中将调用train_iter，或者直接将这部分整合到train函数中）

# %%
def train_iter(model, iterator, optimizer, criterion, clip, nl_field = None):
    model.train()
    epoch_loss = 0
    for i, batch in enumerate(tqdm(iterator)):
        src, src_len = batch.en
        trg = batch.zh
        ##补充训练部分的代码
        optimizer.zero_grad()
        output, attn = model(batch.en, trg)
        output_dim = output.shape[-1]
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)
        loss = criterion(output, trg)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %% [markdown]
# 请补充完成evaluate_iter的代码：
# 该函数用于评测模型在验证集上的效果。
# 生成时可以采用greedy search，即每次直接选择概率最大的词作为输出，直到出现终结符eos或达到最大句子长度，有余力的同学可以尝试用beam search生成。

# %%
def evaluate_iter(model, iterator, en_field, zh_field, criterion):
    model.eval()

    hypothesis, targets = [], []
    eval_loss = 0
    with torch.no_grad():
        for _, batch in enumerate(iterator):
            src, src_len = batch.en
            trg = batch.zh
            ## 得到decoder的输出结果并计算loss，同时获取batch_size
            output,attn = model(batch.en, trg, 0)
            batch_size = output.shape[-2]
            output_dim = output.shape[-1]

            eval_output = output[1:].view(-1, output_dim)
            eval_trg = trg[1:].view(-1)

            loss = criterion(eval_output, eval_trg)
            eval_loss += loss.item()
            
            ##解码每个句子，采用greedy search，每一步选择概率最大的词，可以改进为beam search
            for sent in range(batch_size):
                predicts = []  # 模型生成的文本
                grounds = []   # 参考文本（ground truth）
                
                ## 请补充生成部分的代码
                trg_tensor = output[:,sent,:]
                trg_indexes = []
                for i in range(1,output.shape[0]):
                  pred_token = trg_tensor[i,:].argmax().item()
                  if pred_token == zh_field.vocab.stoi[zh_field.eos_token]:
                    break
                  trg_indexes.append(pred_token)
                  
                
                grd_indexes = []
                for i in range(1,output.shape[0]):
                  pred_token = trg[i,sent]
                  if pred_token == zh_field.vocab.stoi[zh_field.eos_token]:
                    break
                  grd_indexes.append(pred_token)
                  
                  

                predicts = [zh_field.vocab.itos[i] for i in trg_indexes]
                grounds = [zh_field.vocab.itos[i] for i in grd_indexes]
                
                hypothesis.append(' '.join(predicts))
                targets.append(' '.join(grounds))
    
    # 根据模型生成的文本和参考文本计算BLEU值
    bleu = calculate_bleu(hypothesis, targets)  

    return bleu, eval_loss / len(iterator)

# %% [markdown]
# ## 训练模型

# %%
def train(dataloader, model, model_output_path):
    print('Start training...')
    
    ## 补充训练部分的代码，optimizer，计算损失函数的criterion等
    
    optimizer = optim.Adam(model.parameters())
    TRG = dataloader.zh_field
    TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
    criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
    best_loss = 100000
    
    for epoch in range(N_EPOCHS):
        ## 调用train_iter函数
        train_loss = train_iter(model, dataloader.train_iterator, optimizer, criterion, CLIP)
        bleu, loss = evaluate_iter(model, dataloader.dev_iterator, dataloader.en_field, dataloader.zh_field, criterion)
        
        ## 每5个epoch保存一次模型
        if epoch % 5 == 0:
            torch.save(model.state_dict(),'model_'+str(epoch)+'.pt')
        
        ## 计算当前模型在验证集上的效果，如果损失比之前的更小，将当前模型保存为'model_best.pt'
        if loss < best_loss:
            best_bleu = bleu
            best_loss = loss
            torch.save(model.state_dict(), 'model_best.pt')
        
        print(f'Best BLEU: {best_bleu:.3f} | Best Loss:{best_loss:.3f} |  Epoch: {epoch:d} |  BLeu： {bleu:.3f} | Loss:{loss}', flush=True)

# %%
## 参数设定(可以自己修改)
MAX_LEN = 128
TRAIN_BATCH_SIZE = 64
INFERENCE_BATCH_SIZE = 64
HID_DIM = 256
DROPOUT=0.2
N_EPOCHS = 100
CLIP = 1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MODEL_PATH='/content/'

# %%
##定义各个模块
dataloader = Dataloader(TRAIN_BATCH_SIZE, device)
attn = Attention(HID_DIM, HID_DIM)
INPUT_DIM = len(dataloader.en_field.vocab)
OUTPUT_DIM = len(dataloader.zh_field.vocab)
encoder = Encoder(INPUT_DIM, HID_DIM, HID_DIM, HID_DIM, DROPOUT)
decoder = Decoder(OUTPUT_DIM, HID_DIM, HID_DIM, HID_DIM, DROPOUT, attn)
model = Seq2Seq(encoder, decoder, device, dataloader.zh_field.vocab.stoi['<pad>']).to(device)

## 开始训练
train(dataloader, model, model_output_path= MODEL_PATH)
# Out:
#   0%|          | 0/176 [00:00<?, ?it/s]
# en vocab size: 6182 zh vocab size: 4836
# Start training...
# 100%|██████████| 176/176 [00:17<00:00, 10.19it/s]
# Best BLEU: 0.043 | Best Loss:4.973 |  Epoch: 0 |  BLeu： 0.043 | Loss:4.973399324850603
# 100%|██████████| 176/176 [00:17<00:00, 10.23it/s]
# Best BLEU: 0.069 | Best Loss:4.332 |  Epoch: 1 |  BLeu： 0.069 | Loss:4.331590787930922
# 100%|██████████| 176/176 [00:17<00:00, 10.20it/s]
# Best BLEU: 0.078 | Best Loss:4.059 |  Epoch: 2 |  BLeu： 0.078 | Loss:4.059345974163576
# 100%|██████████| 176/176 [00:17<00:00, 10.31it/s]
# Best BLEU: 0.079 | Best Loss:3.928 |  Epoch: 3 |  BLeu： 0.079 | Loss:3.9283003509044647
# 100%|██████████| 176/176 [00:17<00:00, 10.20it/s]
# Best BLEU: 0.079 | Best Loss:3.928 |  Epoch: 4 |  BLeu： 0.075 | Loss:3.941565077413212
# 100%|██████████| 176/176 [00:17<00:00, 10.26it/s]
# Best BLEU: 0.080 | Best Loss:3.908 |  Epoch: 5 |  BLeu： 0.080 | Loss:3.907629446549849
# 100%|██████████| 176/176 [00:17<00:00, 10.21it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 6 |  BLeu： 0.081 | Loss:3.898713697086681
# 100%|██████████| 176/176 [00:17<00:00, 10.19it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 7 |  BLeu： 0.082 | Loss:3.9417662132870066
# 100%|██████████| 176/176 [00:17<00:00, 10.06it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 8 |  BLeu： 0.083 | Loss:3.94968980550766
# 100%|██████████| 176/176 [00:17<00:00, 10.11it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 9 |  BLeu： 0.084 | Loss:3.98931607874957
# 100%|██████████| 176/176 [00:17<00:00, 10.28it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 10 |  BLeu： 0.085 | Loss:3.999457611279054
# 100%|██████████| 176/176 [00:17<00:00, 10.22it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 11 |  BLeu： 0.078 | Loss:4.096289496530186
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 12 |  BLeu： 0.085 | Loss:4.092717615040866
# 100%|██████████| 176/176 [00:17<00:00, 10.15it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 13 |  BLeu： 0.082 | Loss:4.179443573409861
# 100%|██████████| 176/176 [00:17<00:00, 10.15it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 14 |  BLeu： 0.083 | Loss:4.224167130210183
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 15 |  BLeu： 0.083 | Loss:4.2534102472391995
# 100%|██████████| 176/176 [00:17<00:00, 10.21it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 16 |  BLeu： 0.082 | Loss:4.323083014650778
# 100%|██████████| 176/176 [00:17<00:00, 10.16it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 17 |  BLeu： 0.083 | Loss:4.324066549539566
# 100%|██████████| 176/176 [00:17<00:00, 10.20it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 18 |  BLeu： 0.087 | Loss:4.361155427315018
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 19 |  BLeu： 0.087 | Loss:4.411430314183235
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 20 |  BLeu： 0.084 | Loss:4.438928472724828
# 100%|██████████| 176/176 [00:17<00:00, 10.15it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 21 |  BLeu： 0.083 | Loss:4.465086936950684
# 100%|██████████| 176/176 [00:17<00:00, 10.17it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 22 |  BLeu： 0.088 | Loss:4.493700897151774
# 100%|██████████| 176/176 [00:17<00:00, 10.10it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 23 |  BLeu： 0.085 | Loss:4.5440684448588975
# 100%|██████████| 176/176 [00:17<00:00, 10.16it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 24 |  BLeu： 0.086 | Loss:4.6338210729035465
# 100%|██████████| 176/176 [00:17<00:00, 10.17it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 25 |  BLeu： 0.087 | Loss:4.62757408618927
# 100%|██████████| 176/176 [00:17<00:00, 10.21it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 26 |  BLeu： 0.088 | Loss:4.6358950869603595
# 100%|██████████| 176/176 [00:17<00:00, 10.19it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 27 |  BLeu： 0.090 | Loss:4.709001698277214
# 100%|██████████| 176/176 [00:17<00:00, 10.14it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 28 |  BLeu： 0.086 | Loss:4.726533678444949
# 100%|██████████| 176/176 [00:17<00:00, 10.35it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 29 |  BLeu： 0.090 | Loss:4.78228677267378
# 100%|██████████| 176/176 [00:17<00:00, 10.10it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 30 |  BLeu： 0.086 | Loss:4.788808687166735
# 100%|██████████| 176/176 [00:17<00:00, 10.31it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 31 |  BLeu： 0.088 | Loss:4.7972861501303585
# 100%|██████████| 176/176 [00:17<00:00, 10.10it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 32 |  BLeu： 0.086 | Loss:4.868466240438548
# 100%|██████████| 176/176 [00:17<00:00, 10.22it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 33 |  BLeu： 0.086 | Loss:4.9152302958748555
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 34 |  BLeu： 0.087 | Loss:4.914696276187897
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 35 |  BLeu： 0.087 | Loss:4.905583739280701
# 100%|██████████| 176/176 [00:17<00:00, 10.18it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 36 |  BLeu： 0.087 | Loss:4.95905527472496
# 100%|██████████| 176/176 [00:17<00:00, 10.23it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 37 |  BLeu： 0.087 | Loss:5.025691178711978
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 38 |  BLeu： 0.085 | Loss:4.997301024469462
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 39 |  BLeu： 0.084 | Loss:5.059968821027062
# 100%|██████████| 176/176 [00:17<00:00, 10.22it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 40 |  BLeu： 0.086 | Loss:5.09977745197036
# 100%|██████████| 176/176 [00:17<00:00, 10.26it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 41 |  BLeu： 0.086 | Loss:5.124186821959236
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 42 |  BLeu： 0.086 | Loss:5.116248245943677
# 100%|██████████| 176/176 [00:17<00:00, 10.19it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 43 |  BLeu： 0.085 | Loss:5.138240061023018
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 44 |  BLeu： 0.085 | Loss:5.188825355334715
# 100%|██████████| 176/176 [00:17<00:00, 10.15it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 45 |  BLeu： 0.085 | Loss:5.22485243732279
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 46 |  BLeu： 0.087 | Loss:5.203251602974805
# 100%|██████████| 176/176 [00:17<00:00, 10.17it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 47 |  BLeu： 0.085 | Loss:5.260348501530561
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 48 |  BLeu： 0.087 | Loss:5.2714948220686475
# 100%|██████████| 176/176 [00:17<00:00, 10.21it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 49 |  BLeu： 0.090 | Loss:5.293866092508489
# 100%|██████████| 176/176 [00:17<00:00, 10.19it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 50 |  BLeu： 0.087 | Loss:5.307398308407176
# 100%|██████████| 176/176 [00:17<00:00, 10.09it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 51 |  BLeu： 0.084 | Loss:5.385423625057394
# 100%|██████████| 176/176 [00:17<00:00, 10.20it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 52 |  BLeu： 0.088 | Loss:5.32087154821916
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 53 |  BLeu： 0.087 | Loss:5.366894992915067
# 100%|██████████| 176/176 [00:17<00:00, 10.14it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 54 |  BLeu： 0.085 | Loss:5.388840613040057
# 100%|██████████| 176/176 [00:17<00:00, 10.08it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 55 |  BLeu： 0.091 | Loss:5.377936489202759
# 100%|██████████| 176/176 [00:17<00:00, 10.23it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 56 |  BLeu： 0.087 | Loss:5.371506945653395
# 100%|██████████| 176/176 [00:17<00:00, 10.08it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 57 |  BLeu： 0.089 | Loss:5.413949318907478
# 100%|██████████| 176/176 [00:17<00:00, 10.17it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 58 |  BLeu： 0.085 | Loss:5.453006134791807
# 100%|██████████| 176/176 [00:17<00:00, 10.05it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 59 |  BLeu： 0.088 | Loss:5.46539783206853
# 100%|██████████| 176/176 [00:17<00:00, 10.30it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 60 |  BLeu： 0.085 | Loss:5.460895557295192
# 100%|██████████| 176/176 [00:17<00:00, 10.31it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 61 |  BLeu： 0.088 | Loss:5.485906663266095
# 100%|██████████| 176/176 [00:17<00:00, 10.19it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 62 |  BLeu： 0.086 | Loss:5.497216205705296
# 100%|██████████| 176/176 [00:17<00:00, 10.15it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 63 |  BLeu： 0.089 | Loss:5.477291991764849
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 64 |  BLeu： 0.088 | Loss:5.577911154790358
# 100%|██████████| 176/176 [00:17<00:00, 10.22it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 65 |  BLeu： 0.085 | Loss:5.612963568080556
# 100%|██████████| 176/176 [00:17<00:00, 10.14it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 66 |  BLeu： 0.087 | Loss:5.565672932700678
# 100%|██████████| 176/176 [00:17<00:00, 10.29it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 67 |  BLeu： 0.088 | Loss:5.606389406052503
# 100%|██████████| 176/176 [00:17<00:00, 10.14it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 68 |  BLeu： 0.086 | Loss:5.600881172852083
# 100%|██████████| 176/176 [00:17<00:00, 10.34it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 69 |  BLeu： 0.087 | Loss:5.601971333677119
# 100%|██████████| 176/176 [00:17<00:00, 10.02it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 70 |  BLeu： 0.086 | Loss:5.677679568529129
# 100%|██████████| 176/176 [00:17<00:00, 10.08it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 71 |  BLeu： 0.087 | Loss:5.645767564123327
# 100%|██████████| 176/176 [00:17<00:00, 10.03it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 72 |  BLeu： 0.089 | Loss:5.690555317835375
# 100%|██████████| 176/176 [00:17<00:00, 10.16it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 73 |  BLeu： 0.089 | Loss:5.66342706842856
# 100%|██████████| 176/176 [00:17<00:00, 10.06it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 74 |  BLeu： 0.088 | Loss:5.708429406989705
# 100%|██████████| 176/176 [00:17<00:00, 10.10it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 75 |  BLeu： 0.085 | Loss:5.741124583916231
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 76 |  BLeu： 0.087 | Loss:5.716917875138196
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 77 |  BLeu： 0.088 | Loss:5.729238361120224
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 78 |  BLeu： 0.086 | Loss:5.758396630937403
# 100%|██████████| 176/176 [00:17<00:00, 10.21it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 79 |  BLeu： 0.088 | Loss:5.74781379645521
# 100%|██████████| 176/176 [00:17<00:00, 10.14it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 80 |  BLeu： 0.086 | Loss:5.806213439865545
# 100%|██████████| 176/176 [00:17<00:00, 10.09it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 81 |  BLeu： 0.088 | Loss:5.755197855559262
# 100%|██████████| 176/176 [00:17<00:00, 10.21it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 82 |  BLeu： 0.085 | Loss:5.763015419244766
# 100%|██████████| 176/176 [00:17<00:00, 10.18it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 83 |  BLeu： 0.087 | Loss:5.819564524022016
# 100%|██████████| 176/176 [00:17<00:00, 10.09it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 84 |  BLeu： 0.086 | Loss:5.881595134735107
# 100%|██████████| 176/176 [00:17<00:00, 10.23it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 85 |  BLeu： 0.088 | Loss:5.893751919269562
# 100%|██████████| 176/176 [00:17<00:00, 10.17it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 86 |  BLeu： 0.088 | Loss:5.886167496442795
# 100%|██████████| 176/176 [00:17<00:00, 10.05it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 87 |  BLeu： 0.086 | Loss:5.8675973388281735
# 100%|██████████| 176/176 [00:17<00:00, 10.13it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 88 |  BLeu： 0.089 | Loss:5.860954444516789
# 100%|██████████| 176/176 [00:17<00:00, 10.12it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 89 |  BLeu： 0.086 | Loss:5.9447847144170245
# 100%|██████████| 176/176 [00:17<00:00, 10.17it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 90 |  BLeu： 0.087 | Loss:5.94047831676223
# 100%|██████████| 176/176 [00:17<00:00, 10.14it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 91 |  BLeu： 0.089 | Loss:5.9397062117403205
# 100%|██████████| 176/176 [00:17<00:00, 10.22it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 92 |  BLeu： 0.088 | Loss:5.913985306566412
# 100%|██████████| 176/176 [00:17<00:00, 10.15it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 93 |  BLeu： 0.087 | Loss:5.90402583100579
# 100%|██████████| 176/176 [00:17<00:00, 10.05it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 94 |  BLeu： 0.086 | Loss:5.973330054770816
# 100%|██████████| 176/176 [00:17<00:00, 10.31it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 95 |  BLeu： 0.083 | Loss:5.97617980837822
# 100%|██████████| 176/176 [00:17<00:00, 10.07it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 96 |  BLeu： 0.088 | Loss:5.934599800543352
# 100%|██████████| 176/176 [00:17<00:00, 10.08it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 97 |  BLeu： 0.087 | Loss:6.0244188511913475
# 100%|██████████| 176/176 [00:17<00:00, 10.07it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 98 |  BLeu： 0.086 | Loss:6.019261395389384
# 100%|██████████| 176/176 [00:17<00:00, 10.01it/s]
# Best BLEU: 0.081 | Best Loss:3.899 |  Epoch: 99 |  BLeu： 0.085 | Loss:6.032081181352789

# %% [markdown]
# ## 推理部分
# 请补充完成推理（inference）部分的代码，用于在测试集上生成翻译后的文本（该部分与evaluate_iter比较类似）。

# %%
def inference(model, iterator, en_field, zh_field):
    model.eval()

    with torch.no_grad():
        predict_res = []
        for _, batch in enumerate(iterator):
            src, src_len = batch.en
            id, trg = batch.id, batch.zh
            
            ## 得到decoder的输出结果
            output,attn = model(batch.en, trg, 0)
            batch_size = output.shape[-2]
            output_dim = output.shape[-1]
            
            for sent in range(batch_size):
                if en_field is not None:
                    eos_index = [x.item() for x in src[:, sent]].index(en_field.vocab.stoi['<eos>'])
                    src_str = ' '.join([en_field.vocab.itos[x.item()] for x in src[1: eos_index, sent]])
                    sent_id = id[sent]
                predicts = []
                grounds = []
                
                ## 请补充生成部分的代码
                trg_tensor = output[:,sent,:]
                trg_indexes = []
                for i in range(output.shape[0]):
                  pred_token = trg_tensor[i,:].argmax().item()
                  if pred_token == zh_field.vocab.stoi[zh_field.eos_token]:
                    break
                  trg_indexes.append(pred_token)
                  
                grd_indexes = []
                for i in range(1,output.shape[0]):
                  pred_token = trg[i,sent]
                  if pred_token == zh_field.vocab.stoi[zh_field.eos_token]:
                    break
                  grd_indexes.append(pred_token)
                  

                predicts = [zh_field.vocab.itos[i] for i in trg_indexes]
                grounds = [zh_field.vocab.itos[i] for i in grd_indexes]
                
                predict_res.append((int(sent_id), src_str, ' '.join(predicts), " ".join(grounds)))

    predict_res = [(item[1],item[2], item[3] ) for item in sorted(predict_res, key=lambda x: x[0])]

    bleu = calculate_bleu([i[1] for i in predict_res], [i[2] for i in predict_res])
    return bleu, predict_res

# %% [markdown]
# 读取效果最好的模型，在测试集上进行生成：

# %%
dataloader = Dataloader(INFERENCE_BATCH_SIZE, device, eval=True)
model_init_path = f"{MODEL_PATH}/model_best.pt"
model = Seq2Seq(encoder, decoder, device, dataloader.zh_field.vocab.stoi['<pad>']).to(device)
model.load_state_dict(torch.load(model_init_path))
bleu, predict_output = inference(model, dataloader.test_iterator, dataloader.en_field, dataloader.zh_field)
for item in predict_output:
    src, trg, golden = item
    print(f"src:{src}\ntrg:{trg}\ngolden:{golden}\n")
print(bleu)
# Out:
# Streaming output truncated to the last 5000 lines.
# trg:<unk> 如何 找到 的 执行 而 不 执行 ？
# golden:如何 在 不 阻塞 的 情况 下 检查 按键 ？
#
# src:output not more than size bytes to str according to the format string format and the extra arguments
# trg:<unk> 不 一定 要 size size 个 字节 字符串 的 大小 格式 字符串
# golden:根据 格式 字符串 format 和 额外 参数 ， 输出 不 超过 size 字节 到 str
#
# src:author: guido van rossum
# trg:<unk> 作者 : guido van "
# golden:作者 : guido van rossum
#
# src:in certain <unk> cases, though, modules are built right in their installation directory, so this is <unk> a useful ability
# trg:<unk> 在 <unk> 中 ， ， ， ， 模块 是 ， ， 因此 ， 因此 ， 因此 ， 因此 ， 因此 ， 因此 ， 所以 ， 所以 会 很 有用 的
# golden:不过 在 某些 特殊 情况 下 ， 模块 是 在 其 安装 目录 中 被 构建 的 ， 因此 这 可能 会 是 个 有用 的 功能
#
# src:it is the <unk> responsibility to ensure that all whitespace and special characters are quoted appropriately to avoid shell <unk> <unk>
# trg:<unk> 它 被 设计 的 所有 特殊字符 ， 所有 特殊字符 的 所有 特殊字符 ， 并且 ， 并且 ， 并且 被 视为 的 的 ， 并且 需要 <unk> 避免 干扰 避免
# golden:应用程序 要 负责 确保 正确 地 转义 所有 空白 字符 和 特殊字符 以 防止 shell 注入 漏洞
#
# src:another use is to pass a small function as an argument:
# trg:<unk> 另 一个 使用 " 作为 一个 一个 作为 一个 作为 一个
# golden:另 一个 用法 是 传递 一个 小 函数 作为 参数 :
#
# src:on windows illegal characters <unk> <unk> <unk> <unk> <unk> <unk> and " ") replaced by underscore <unk>
# trg:<unk> 在 windows 系统 上 ， " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " "
# golden:在 windows 上 非法 字符 ( " : " , " < " , " > " , " | " , " " " , " ? " , and " " ) 会 被 替换 为 下划线 ( " _ " )
#
# src:what's new in python 3.1
# trg:<unk> python 3.1 有 什么 新 变化
# golden:python 3.1 有 什么 新 变化
#
# src:changes to the development process
# trg:<unk> 将 的 变化
# golden:开发 过程 的 变化
#
# src:the sole value of the type <unk>
# trg:<unk> " type " 类型 的 类型
# golden:" <unk> " 类型 的 唯一 值
#
# src:what is python good <unk>
# trg:<unk> 什么 是 python 的 ？
# golden:python 适合 做 什么 ？
#
# src:functions such as <unk> and built in "__import__()" can also be used to invoke the import <unk>
# trg:<unk> 函数 这样 的 " <unk> ( ) " 和 " 内置 ( ) " ， 也 可以 在 可以 被 导入 导入 导入 导入 导入 导入 导入
# golden:" importlib . import _ module ( ) " 以及 内置 的 " __ import __ ( ) " 等 函数 也 可以 被 用来 发起 调用 导入 机制
#
# src:some typical values include: <unk> or <unk>
# trg:<unk> 某些 变量 : " " " " " 或 " " " " " " " "
# golden:一些 典型 的 值 包括 : " " <unk> " " 或 " " common " "
#
# src:header is a flag which controls if spaces are encoded as underscores as per rfc <unk> .
# trg:<unk> 如果 是 一个 空 的 ， 则 会 被 打印 空格 为 " true " 的 rfc
# golden:header 旗标 控制 空格符 是否 要 编码 为 下划线 ， 具体 描述 见 rfc <unk>
#
# src:cpython supports two different calling <unk> <unk> and <unk>
# trg:<unk> cpython 支持 两个 不同 的 " <unk> " , " <unk> " 和 " <unk> "
# golden:cpython 支持 两种 不同 的 调用 协议 ： tp _ call 和 矢量 调用
#
# src:function and method decorators were introduced in pep <unk> .
# trg:<unk> 函数 和 方法 在 " io . <unk> ( ) " 中
# golden:函数 和 方法 装饰 器 是 在 pep <unk> 中 被 引入 的
#
# src:out of <unk> <unk> are <unk> in a manner consistent with the handling of normal <unk>
# trg:<unk> <unk> <unk> <unk> 在 <unk> 中 的 " <unk> " 的 " 的 "
# golden:<unk> 的 索引 <unk> 以 与 普通 切片 一致 的 方式 进行 剪切
#
# src:the system will save old log files by appending extensions to the filename
# trg:<unk> 将 系统 将 将 将 将 将 将 被 添加 到 文件 所 使用 的 文件
# golden:系统 将 通过 为 文件名 添加 扩展名 来 保存 旧 日志 文件
#
# src:if the previous name stored in the capsule was not "null", no attempt is made to free it.
# trg:<unk> 如果 没有 名称 的 名称 ， 则 " " " ， 则 " null " ， 则 将 不会 被 设置
# golden:如果 之前 保存 在 capsule 中 的 name 不 为 " null " ， 则 不会 尝试 释放 它
#
# src:analogous to <unk> but for container objects with the <unk> flag set.
# trg:<unk> " <unk> " <unk> " ， 但 与 " <unk> " 对象 的 "
# golden:类似 于 " pyobject _ new ( ) " ， 适用 于 设置 了 " py _ <unk> _ <unk> _ gc " 标签 的 容器 对象
#
# src:after starting the <unk> one of two options may be <unk>
# trg:<unk> 之后 开始 （ （ 可能 ） ， 其中 之一 可能 的 选项 之一
# golden:启动 安装程序 后 ， 可以 选择 以下 两个 选项 之一 ：
#
# src:if the environment variable "pythonpath" exists, as described in environment variables, its entries are added next
# trg:<unk> 如果 设置 了 设置 上述 ， 则 在 ， 中 的 按 其 优先级 条目 添加 条目
# golden:如果 环境变量 " pythonpath " 存在 ， 如 环境变量 中 所述 ， 则 接下来 添加 其 条目
#
# src:the return value is a "float" similar to that returned by <unk>
# trg:<unk> 返回值 是 一个 一个 " 的 " 的 " 的 " ) " 返回 一个 的 的 的
# golden:此 返回值 是 与 " time . time ( ) " 返回值 类似 的 " float " 对象
#
# src:raised when there is an authentication error.
# trg:<unk> 当 " 错误 时 引发 错误 时 错误 错误
# golden:出现 身份验证 错误 时 引发
#
# src:some examples of <unk>
# trg:<unk> 一些 " class " 的 示例
# golden:一些 用法 示例 ：
#
# src:changes in python behavior
# trg:<unk> python 行为 的 变化 变化
# golden:python 行为 的 改变
#
# src:changed in version 3.6: out of range port numbers now raise "valueerror", instead of returning "none".
# trg:<unk> 在 3.6 版 更改 : <unk> of " now supports " " " 而 不是 " none "
# golden:在 3.6 版 更改 : out of range port numbers now raise " valueerror " , instead of <unk> " none " .
#
# src:when <unk> returns "false", the payload should be a string object (which might be a <unk> encoded binary <unk>
# trg:<unk> 当 " " " " " ， " 应当 返回 一个 字符串 ， ， 对象 ， 一个 一个 " <unk> " 编码 格式
# golden:在 " is _ multipart ( ) " 返回 " true " 的 场合 下 ， <unk> 应当 是 一个 字符串 对象 （ 有 可能 是 一个 使用 了 内容 传输 编码 进行 编码 的 二进制 <unk> ）
#
# src:parameters: name a string which is a valid <unk>
# trg:<unk> 参数 : 一个 字符串 ， 有效 的 有效
# golden:参数 : name 一个 有效 的 形状 名 字符串
#
# src:supported ini file structure
# trg:<unk> 支持 的 文件 的 文件
# golden:受 支持 的 ini 文件 结构
#
# src:<unk> and antoine pitrou, bpo <unk>
# trg:<unk> <unk> 和 antoine pitrou 在 bpo <unk> 中 贡献 。 ）
# golden:<unk> 和 antoine pitrou 在 bpo <unk> 中 贡献 。 ）
#
# src:when a header parameter is encoded in rfc 2231 format, <unk> may return a 3 tuple containing the character set, language, and value
# trg:<unk> 当 一个 形 参会 中 ， " " " " " " " ， " 的 时候 ， ， 包含 一个 包含 包含 字符 的 元组 ， 包含 字符 的 值 ， 元组
# golden:<unk> rfc 2231 格式 来 编码 <unk> <unk> ， " message . get _ <unk> " 可能 返回 一个 包含 字符集 、 语言 和 值 的 3 元组
#
# src:the following table gives an overview of the known <unk> and whether the various modules are <unk> to them.
# trg:<unk> 以下 了 以下 了 的 的 的 的 的 的 ， ， 这些 是 如何 的 的 的 的 的 <unk>
# golden:下表 概述 了 已知 的 攻击 以及 各种 模块 是否 容易 受到 攻击
#
# src:to see how <unk> is implemented in terms of the descriptor <unk> here is a pure python <unk>
# trg:<unk> 请参阅 查看 如何 <unk> <unk> 描述 <unk> 描述 ， 描述 <unk> 是 python 是 python 的 python
# golden:要 了解 " property ( ) " 如何 根据 描述 器 协议 实现 ， 这里 是 一个 纯 python 的 等价 实现 如下 :
#
# src:on failure, set an exception and return "null".
# trg:<unk> 在 失败 时 设置 一个 异常 并 返回 " null "
# golden:在 失败 时 设置 一个 异常 并 返回 " null "
#
# src:applications can use the <unk> function attribute to determine which case applies.
# trg:<unk> 应用程序 可以 使用 " <unk> " 函数 来 使用 " <unk> "
# golden:应用程序 可以 使用 " rmtree . <unk> _ <unk> _ <unk> " 函数 属性 来 确定 <unk> 具体 是 哪 一些
#
# src:pickles the record's attribute dictionary and writes it to the socket in binary format
# trg:<unk> 将 记录 属性 字典 字典 并 将 其 写入 二进制 格式 写入 格式
# golden:对 记录 的 属性 字典 执行 封存 并 以 二进制 格式 将 其 写入 套 接字
#
# src:this variety of "nan" is quiet and, once created, will flow through other computations always resulting in another "nan"
# trg:<unk> 对于 这个 目的 是 为了 防止 被 设计 其他 其他 其他 的 ， 很 直观 ， 很 有用 的
# golden:这样 的 " nan " 是 静默 产生 的 ， 并且 在 产生 之后 参与 其它 计算 时 总是 会 得到 " nan " 的 结果
#
# src:return a string describing the class of the operand
# trg:<unk> 返回 一个 的 的 的 的
# golden:返回 一个 字符串 描述 运算 数 的 class
#
# src:changed in version 3.5: added the <unk> parameter.
# trg:<unk> 在 3.5 版 更改 : 增加 了 <unk> _ <unk> 形参
# golden:在 3.5 版 更改 : 添加 了 <unk> _ <unk> 形参
#
# src:if there are positional arguments, there must be as many as there are items in <unk> they will be assigned as attributes of these names.
# trg:<unk> 如果 有 实参 参数 ， 则 必须 为 " none " ， 它们 将 它们 将 这些 这些 属性 的 属性
# golden:如果 有 位置 参数 ， 它们 必须 和 " t ._ fields " 中 的 元素 一样 多 ； 他们 会 像 这些 名字 的 属性 一样 被 赋值
#
# src:resulting state <unk> state r flag r flag o flag o flag d flag d flag f flag f flag a flag a flag
# trg:<unk> " 状态 " 状态 状态 r 标记 r 标记 r 标记 r 标记 标记 " 标志 标记 标记 标志 旗标
# golden:结果 状态 " <unk> " 状态 r 标记 r 标记 o 标记 o 标记 d 标记 d 标记 f 标记 f 标记 a 标记 a 标记
#
# src:changed in version 3.2: added context manager support.
# trg:<unk> 在 3.2 版 更改 : 添加 上下文 管理器 支持
# golden:在 3.2 版 更改 : 添加 了 上下文 管理器 支持
#
# src:<unk> allows you to add or remove features by modifying the <unk> unchanged <unk> will not install or remove anything
# trg:<unk> " <unk> ( ) " 或 " <unk> " 或 " <unk> " ) " 或 " 不会 " 不会 不 一定 或 或 或
# golden:“ 修改 ” 允许 您 通过 修改 <unk> 来 添加 或 删除 功能 未 更改 的 <unk> 将 不会 安装 或 删除 任何 内容
#
# src:leading whitespace is significant in python <unk>
# trg:<unk> python <unk> 是 在 <unk> 中 的 python
# golden:请 注意 前导 空格 在 python 语句 中是 有 重要 作用 的 ！
#
# src:<unk> is the event name as c string, <unk> is a "pyobject" pointer to a tuple object.
# trg:<unk> " <unk> " " " " 是 " c " 的 一个 " " " 的 一个 一个 一个 一个 一个 一个 " 对象
# golden:" <unk> " 是 事件 名称 的 c 字符串 ， " arg1 " 是 一个 指向 元组 对象 的 " pyobject " 指针
#
# src:<unk> is a subclass of the built in "dict" class
# trg:<unk> " 是 " " " " 的 " dict " 的 子类 的 子类
# golden:" defaultdict " 是 内置 " dict " 类 的 子类
#
# src:changed in version 3.9: classes may be decorated with any valid <unk>
# trg:<unk> 在 3.9 版 更改 : 类 可以 使用 " <unk> " 的 有效
# golden:在 3.9 版 更改 : 类 可 使用 任何 有效 的 " <unk> _ expression " 来 装饰
#
# src:"html" hypertext markup language support
# trg:<unk> " html " 超文本 语言 语言 支持
# golden:" html " 超文本 标记 语言 支持
#
# src:changed in version 3.4: <unk> parameter was added.
# trg:<unk> 在 3.4 版 更改 : <unk> _ <unk> _ address _
# golden:在 3.4 版 更改 : 添加 了 <unk> 形参
#
# src:it is an error to call this function if the <unk> on the input bytes object is not one
# trg:<unk> 如果 此 函数 的 未 正确 的 的 ， 此 方法 会 被 该 对象
# golden:如果 输入 字节 串 对象 的 引用 计数 不 为 <unk> 调用 此 函数 将 报错
#
# src:<unk> is a list of names to <unk> and defaults to <unk> <unk>
# trg:<unk> " 是 " 名称 的 名称 列表 名称 的 默认值 为 " default _ default _ <unk> "
# golden:<unk> 是 需要 隐藏 的 文件名 列表 ， 且 默认 为 " [ os . <unk> , os . <unk> ] "
#
# src:as <unk> to the <unk> <unk> method:
# trg:<unk> 作为 <unk> <unk> <unk> <unk> <unk>
# golden:而 相应 的 更 简洁 更 <unk> 的 方法 是 这样 的 :
#
# src:if seed is given, creates a new instance of the underlying random number generator
# trg:<unk> 如果 " 为 " ， 则 创建 一个 新 的 的 " 创建 " 的 的 一个 新 的
# golden:当 给定 <unk> 时 ， 创建 一个 新 的 底层 随机数 生成器 实例
#
# src:"argumentparser" objects allow the help formatting to be customized by specifying an alternate formatting class
# trg:<unk> argumentparser 对象 通过 帮助 的 的 " __ ( ) " 来 获取 一个 一个
# golden:" argumentparser " 对象 允许 通过 指定 备用 格式化 类 来自 定义 帮助 格式
#
# src:a string <unk> <unk> the reason this error occurred, for example <unk>
# trg:<unk> 字符串 表示 根包 的 错误 的 错误 ， 这种 错误
# golden:一个 字符串 形式 的 <unk> ， 用来 指明 发生 错误 的 原因 ， 例如 " <unk> _ verify _ <unk> "
#
# src:when both mapping and <unk> are given and there are duplicates, the placeholders from <unk> take <unk>
# trg:<unk> 当 两个 映射 和 和 <unk> ， 以及 <unk> 的 从 ， 从 从 " <unk> " 中 的 "
# golden:当 同时 给出 mapping 和 <unk> 并且 存在 重复 时 ， 则 以 <unk> 中 的 占位 <unk> 优先
#
# src:new in version 3.8: " <unk> argument enhanced to support ipv6
# trg:<unk> 3.8 新版 功能 : " follow _ string " " " 支持 " 支持
# golden:3.8 新版 功能 : " <unk> " argument <unk> to support ipv6
#
# src:new in version 3.8.
# trg:<unk> 3.8 新版 功能 .
# golden:3.8 新版 功能 .
#
# src:replacing "os.popen()", "os.popen2()", "os.popen3()"
# trg:<unk> 替代 " os . popen ( ) " , " os . popen2 ( ) " , " os . popen3 ( ) " , " os
# golden:替代 " os . popen ( ) " , " os . popen2 ( ) " , " os . popen3 ( ) "
#
# src:"ctypes" will create descriptor s which allow reading and writing the fields by direct attribute accesses
# trg:<unk> " ctypes " 将 创建 和 创建 文件 的 的 ， 以及 " 查找 " 的 " 属性
# golden:" ctypes " 将 创建 <unk> ， 它 允许 通过 直接 属性 访问 来 读取 和 写入 字 段
#
# src:if you want to parse python code into its ast representation, see <unk>
# trg:<unk> 如果 你 想 代码 代码 代码 代码 ， 请 将 其 <unk> <unk>
# golden:如果 您 想 分析 python 代码 的 ast 表示 ， 请参阅 " ast . parse ( ) "
#
# src:the <unk> structure got a new <unk> field
# trg:<unk> " <unk> _ <unk> ( ) " 结构 体 的 新 的 新 的 新 的
# golden:" <unk> " 结构 体 添加 了 一个 新 的 cf _ feature _ version 字 段
#
# src:when you have done this, you can <unk> your application without requiring your users to install python.
# trg:<unk> 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 你 的 你 的 你 的 你 的 你 的 你 的 你 的
# golden:完成 此 操作 后 ， 您 可以 分发 应用程序 ， 而 无需 用户 安装 python
#
# src:so, if that data is needed later, it should be stored as a <unk>
# trg:<unk> 所以 ， 如果 data 为空 ， 则 将 它 应当 为 " null " ， 它 将 被 作为
# golden:因此 如果 稍后 还 需要 返回 结果 ， 可 保存 为 列表 ：
#
# src:changed in version 3.3: in version 3.2, "strftime()" method was restricted to years > <unk>
# trg:<unk> 在 3.3 版 更改 : <unk> " strftime ( ) " 方法 在 限于 <unk> .
# golden:在 3.3 版 更改 : 在 版本 3.2 中 ， " strftime ( ) " 方法 只 限于 <unk> > 1000
#
# src:subclasses of this class are documented in section <unk> subclasses and <unk> operation with web <unk>
# trg:<unk> 这个 类 的 的 " <unk> 节 " , " ' nfkc ' " , " ' " , " ' " , " ' " , " ' "
# golden:子类 的 文档 位于 段落 <unk> <unk> and co <unk> with web <unk>
#
# src:allows opening for read or <unk> text or binary through supported <unk> <unk> <unk> <unk> <unk>
# trg:<unk> 允许 读取 或 读取 或 二进制 或 二进制 （ 二进制 ） 或 二进制 ） （ 二进制 ） ） ） ）
# golden:允许 通过 支持 的 模式 打开 用于 读取 或 写入 文本 或 二进制 数据 : ' r ' , ' w ' , ' rb ' , ' <unk> '
#
# src:for example, the code, "if key in mapping: return <unk> can fail if another thread removes key from mapping after the <unk> but before the lookup
# trg:<unk> 例如 ， ， " 在 " 中 ， 如果 可能 在 " 中 ( ) " ， 则 返回 一个 在 在 在 在 在 " 中 获取 的 的 ， 则 可能 在 " <unk> ( ) " 方法
# golden:例如 ， 以下 代码 " if key in mapping : return mapping [ key ] " 可能 由于 在 检查 操作 之后 其他 线程 从 mapping <unk> 除了 key 而 出错
#
# src:"abc" abstract base classes
# trg:<unk> " abc " 抽象 基类
# golden:" abc " 抽象 基类
#
# src:a generator expression is a compact generator notation in <unk>
# trg:<unk> 生成器 表达式 表达式 表达式 生成器 表达式 生成器 的 生成器 " 生成器 "
# golden:生成器 表达式 是 用 圆括号 括 起来 的 紧凑 形式 生成器 标注
#
# src:new in version 3.5.
# trg:<unk> 3.5 新版 功能 .
# golden:3.5 新版 功能 .
#
# src:(contributed by <unk> j
# trg:<unk> （ 由 <unk> <unk> <unk>
# golden:（ 由 <unk> j
#
# src:class that <unk> a string object
# trg:<unk> class " 类 " 类 的 字符串
# golden:模拟 一个 字符串 对象
#
# src:instances of this exception provide three interesting attributes: "msg" is a textual explanation of the error, "filename" is the name of the source file, and <unk> gives the line number on which the error was found.
# trg:<unk> 此 方法 会 提供 了 一种 的 的 的 的 的 的 ， 这是 是 的 的 的 的 " ， " ， 而 不是 " 的 " <unk> "
# golden:此 异常 的 实例 提供 了 三个 有用 属性 : " msg " 为 错误 的 文本 说明 ， " filename " 为 源文件 的 名称 ， 而 " <unk> " 给出 了 错误 所在 的 行号
#
# src:implicitly continued lines can carry comments
# trg:<unk> 隐式 拼接 行 可以 可以 可以 轻松
# golden:隐式 的 行 拼接 可以 带有 注释
#
# src:the <unk> is the type used for dictionaries that are read from the plist file.
# trg:<unk> " <unk> " 用于 用于 的 的 的 的 从 用于 读取 的 的
# golden:dict _ type 为 字典 用来 从 plist 文件 读取 的 类型
#
# src:creating a struct object once and calling its methods is more efficient than calling the "struct" functions with the same format since the format string only needs to be compiled once.
# trg:<unk> 创建 一个 对象 的 方法 ， 它 通过 调用 " __ ( ) " 方法 的 函数 ， 因为 它 只 需要 只 需要 只 需要 的 的
# golden:一次性 地 创建 struct 对象 并 调用 其 方法 相比 使用 同样 的 格式 调用 " struct " 函数 更为 高效 ， 因为 这样 格式 字符串 只 需 被 编译 一次
#
# src:changes in the c api
# trg:<unk> c api 的 变化
# golden:c api 中 的 改变
#
# src:for example: <unk> y for x in <unk> for y in <unk> <unk>
# trg:<unk> 例如 : x x x x x x " y " x in " y " in " in "
# golden:例如 : " ( x y for x in range ( 10 ) for y in range ( x , x + 10 ) ) " .
#
# src:receive a message, calculate the digest of the message using <unk> as the key, and then send the digest <unk>
# trg:<unk> 将 一个 " 使用 " <unk> ( ) " ) " ， ， 然后 使用 的 然后 然后 ， 然后 ， 然后 ， 然后 ，
# golden:接收 一条 信息 ， 使用 authkey 作为 键 计算 信息 摘要 ， 然后 将 摘要 发送 <unk>
#
# src:new in version 3.7.
# trg:<unk> 3.7 新版 功能 .
# golden:3.7 新版 功能 .
#
# src:key is an already open key, or one of the predefined hkey_ constants.
# trg:<unk> key 为 某个 已经 打开 的 键 ， 或者 预定 义 的 hkey _ 常量 之一
# golden:key 为 某个 已经 打开 的 键 ， 或者 预定 义 的 hkey _ 常量 之一
#
# src:this <unk> that most <unk> of a long sequence can never be generated
# trg:<unk> 这 这 大多数 的 的 序列 ， 可以 可以 轻松 地为
# golden:这 意味着 长 序列 的 大多数 排列 永远 不会 产生
#
# src:this function does not check whether the data points are at least interval <unk>
# trg:<unk> 此 函数 不 不 检查 不 执行 数据 的 数据 点
# golden:此 函数 不会 <unk> 点 之间 是否 至少 <unk> <unk> 的 距离
#
# src:to change it for all <unk> for example if you want all logging times to be shown in <unk> set the <unk> attribute in the "formatter" class.
# trg:<unk> 为了 改变 ， 所有 <unk> ， 如果 你 的 所有 <unk> 所有 <unk> 的 <unk> ， 则 <unk> " <unk> " 属性 中 的 " 属性
# golden:要 为 所有 格式化 程序 更改 此项 ， 例如 当 你 希望 所有 日志 时间 都 显示 为 <unk> ， 请 在 " formatter " 类中 设置 " converter " 属性
#
# src:using python on unix platforms
# trg:<unk> 在 unix 平台 上 使用 python
# golden:在 unix 平台 中 使用 python
#
# src:returns "false" for broken symbolic links
# trg:<unk> 返回 " false " ， 则 返回 "
# golden:对于 失效 的 符号 链接 ， 返回 " false "
#
# src:determine whether code is in <unk> <unk> ascii control <unk>
# trg:<unk> 确定 code 是否 属于 <unk> <unk> ascii ascii 控制字符 ascii 控制
# golden:确定 code 是否 属于 <unk> . 2 ( 非 ascii 控制字符 )
#
# src:errors is an optional string that specifies how encoding and decoding errors are to be <unk> cannot be used in binary mode
# trg:<unk> errors 是 一个 可选 的 字符串 ， 指明 编码 格式 编码 格式 编码 格式 编码 格式 编码 格式 ， 并且 ， 并且 可以 被 使用 二进制 模式
# golden:errors 是 一个 可选 的 字符串 参数 ， 用于 指定 如何 处理 编码 和 解码 错误 这 不能 在 二进制 模式 下 使用
#
# src:end of lines are automatically included in the string, but it's possible to prevent this by adding a "\" at the end of the line
# trg:<unk> 在 行 的 的 的 ， 但 ， 但 ， 但 通过 添加 一个 " " ( ) " 方法
# golden:字符串 中 的 回车 换行 会 自动 包含 到 字符串 中 ， 如果 <unk> 包含 ， 在 行尾 添加 一个 " \ " 即可
#
# src:the first four lines correspond to the arguments of the <unk> method.
# trg:<unk> 第一个 参数 的 " 参数 ( ) " 方法 参数
# golden:开头 的 <unk> 对应 " screen . setup ( ) " 方法 的 参数
#
# src:the object must not be "null"; if you aren't sure that it isn't "null", use <unk>
# trg:<unk> 如果 必须 不 需要 ， 你 使用 ， 它 可以 使用 " null " ， 使用 " 使用 " "
# golden:对象 必须 不 为 " null " ； 如果 你 不 确定 它 不 为 " null " ， 可 使用 " py _ <unk> ( ) "
#
# src:the flags parameter should be a bitwise or of <unk> <unk> and <unk>
# trg:<unk> 形参 参数 是 一个 <unk> <unk> <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> "
# golden:flags 形参 应当 " os . o _ append " , " os . o _ <unk> " 和 " os . o _ text " 按位 or 的 结果
#
# src:when maxsplit is nonzero, at most maxsplit <unk> will be made, and the remainder of the string is returned as the final element of the list
# trg:<unk> 当 <unk> <unk> <unk> <unk> ， <unk> ， 将 被 的 的 为 字符串 的 的 的 的 ， 返回 的 返回 返回 的 的 的
# golden:当 maxsplit 非 零时 ， 将 最 多 进行 maxsplit 次 拆分 ， 并且 字符串 的 其余部分 将 作为 列表 的 最后 一个 元素 返回
#
# src:in order to correctly <unk> with the abstract base class <unk> the descriptor must identify itself as abstract using <unk>
# trg:<unk> 为了 " " " 的 " ， " ， " ， " ， " ) " ， 使用 " " " " 使用 " 的 " ( ) " ) " 方法
# golden:为了 能 正确 地 与 抽象 基类 机制 实现 <unk> ， 描述符 必须 使用 " __ <unk> __ " 将 自身 标识 为 抽象 的
#
# src:if, after 10 <unk> the bytes cannot be <unk> "oserror" is raised.
# trg:<unk> 在 之后 之后 10 ， 字节 字节 字节 ， 字节 字节 ， 字节 会 被 引发 " oserror "
# golden:如果 在 10 次 尝试 后 字节 数据 仍 无法 被 锁定 ， 则 会 引发 " oserror "
#
# src:using lists as queues
# trg:<unk> 使用 作为 作为
# golden:列表 作为 队列 使用
#
# src:the "fractions" and "decimal" modules make these calculations <unk>
# trg:<unk> " " " 模块 " 模块 模块 这些 这些 这些 这些
# golden:" fractions " 和 " decimal " 模块 <unk> 进行 此类 计算 更加 容易 :
#
# src:to allow users to easily install a <unk> copy of python without the test <unk> you could provide a shortcut with the following command
# trg:<unk> 为了 允许 用户 代码 在 python python ， python 开发者 ， ， ， 可以 用 的 <unk> ， 你 可以 用 以下 代码
# golden:要 允许 用户 在 没有 测试 套件 的 情况 下 轻松 安装 python 的 <unk> 副本 ， 可以 使用 以下 命令 提供 快捷方式
#
# src:changed in version 3.7: default value of repeat changed from 3 to <unk>
# trg:<unk> 在 3.7 版 更改 : repeat 从 从 从 3 的 默认值
# golden:在 3.7 版 更改 : repeat 的 默认值 由 3 更 改为 5
#
# src:most functions that return a reference to an object pass on ownership with the reference
# trg:<unk> 在 函数 返回 一个 引用 对象 引用 对象 引用 对象 引用 对象 对象
# golden:大多数 函数 返回 一个 对象 的 引用 ， 并 传递 引用 拥有 关系
#
# src:"\w" matches any non alphanumeric <unk> this is equivalent to the class <unk> <unk> <unk> <unk>
# trg:<unk> 而 非 任何 任何 任何 任何 （ 即 " str " " " " " " " " " " " " ) "
# golden:" \ w " 匹配 任何 非 字母 与 数字 字符 ； 这 相当于 类 " [ ^ a <unk> <unk> 9 _ ] "
#
# src:reserved classes of identifiers
# trg:<unk> 保留 的 标识符 类
# golden:保留 的 标识符 类
#
# src:the frame argument must not be "null".
# trg:<unk> 如果 参数 必须 为 " null "
# golden:frame 参数 必须 不 为 " null "
#
# src:the class which implements the sequence behavior provided by the module is available for subclassing as <unk>
# trg:<unk> 这个 类 实现 所 提供 了 " 模块 提供 了 " 的 " 模块 提供 了 " 的 " 模块 提供 了 " 模块
# golden:此 模块 所 提供 的 实现 了 序列 行为 的 类 同样 也 可 用于 子 类化 ：
#
# src:"shutil" high level file operations
# trg:<unk> " shutil " 高阶 文件 操作
# golden:" shutil " 高阶 文件 操作
#
# src:the line number, for the first instruction of each line
# trg:<unk> 行 的 的 的 的 的 的 的 行
# golden:行号 ， 用于 <unk> 的 <unk> 指令
#
# src:changed in version 3.8: previously, zip archives with an archive comment were not supported.
# trg:<unk> 在 3.8 版 更改 : 在 windows 上将 版本 中 使用 " async " 的 支持
# golden:在 3.8 版 更改 : 以前 ， 不 支持 带有 档案 注释 的 zip 档案
#
# src:returns the o converted to an integer object on success, or "null" on failure
# trg:<unk> 返回 o 转换 为 一个 对象 的 对象 ， 返回 一个 null " null " null "
# golden:成功 时 返回 o 转换 为 整数 对象 后 的 结果 ， 失败 时 返回 " null "
#
# src:(contributed by <unk> <unk> in bpo <unk>
# trg:<unk> （ 由 <unk> <unk> 在 bpo <unk> 中 贡献 。 ）
# golden:（ 由 <unk> <unk> 在 bpo <unk> 中 贡献 。 ）
#
# src:the following functions are available for instances of "set" or its <unk> but not for instances of "frozenset" or its <unk>
# trg:<unk> 这些 函数 的 实现 的 " datetime . set ( ) " 或 " ) " 方法 ， 但 不 为 " 实例 的 实例 ， 而 不是 " 实例 " 实例
# golden:下列 函数 适用 于 " set " 或 其子 类型 的 实例 ， 但 不可 用于 " frozenset " 或 其子 类型 的 实例
#
# src:new in version 3.4.
# trg:<unk> 3.4 新版 功能 .
# golden:3.4 新版 功能 .
#
# src:also, a strict reading of the original <unk> rfc <unk> standard calls for a two digit year <unk> rather than <unk> but practice moved to 4 digit years long before the year <unk>
# trg:<unk> 在 " <unk> " 的 " ， " ， 标准 （ 标准 （ 标准 ） 标准 ） ， ） ， ） ， 而 不是 标准 的 ， 但 ， 但 ， 但 在 其他 情况 下 ， 但 在 其他 情况 下 ， 但 在 其他 情况 下
# golden:此外 ， 严格 的 <unk> 年 原始 rfc <unk> 标准 要求 <unk> 的 年份 （ % y 而 不是 % y ） ， 但是 实际 在 2000 年 之前 <unk> 就 <unk> 到 了 4 位数 年
#
# src:the memory could be a <unk> constant array in a c <unk> it could be a raw block of memory for manipulation before passing to an operating system library, or it could be used to pass around structured data in its <unk> in memory format.
# trg:<unk> 内存 可以 是 一个 c c 结构 体 的 ， ， 它 在 在 在 其他 情况 下 ， 它 在 在 在 在 在 在 内存 中 使用 的 中 使用 "
# golden:内存 可以 是 c 扩展 中 的 一个 大 的 常量 数组 ， 也 可以 是 在 传递 到 操作系统 库 之前 用于 操作 的 原始 内存 块 ， 或者 可以 用来 传递 本 机 内存 格式 的 结构化 数据
#
# src:if an instance's dictionary has an entry with the same name as a non data descriptor, the dictionary entry takes <unk>
# trg:<unk> 如果 字典 字典 字典 将 一个 与 名称 的 名称 ， 则 返回 一个 字典 的 字典
# golden:如果 实例 的 字典 具有 与非 数据 描述 器 同名 的 条目 ， 则 该 字典 条目 优先
#
# src:in that case, <unk> will add "__setattr__()" and "__delattr__()" methods to the class
# trg:<unk> 在 ， 情况 下 ， " 将 " 添加 " 和 " 类 的 方法
# golden:在 这种 情况 下 ， 数据 类 将 向 类 添加 " __ setattr __ ( ) " 和 " __ delattr __ ( ) " 方法
#
# src:if you choose to use these attributes in logged <unk> you need to <unk> some care
# trg:<unk> 如果 你 想要 使用 ， 你 希望 <unk> ， 你 需要 需要 的 一些
# golden:如果 在 已 记录 的 消息 中 使用 这些 属性 ， 则 需要 <unk> 小心
#
# src:changed in version 3.2: the creation of a "logrecord" has been made more <unk> by providing a factory which is used to create the record
# trg:<unk> 在 3.2 版 更改 : 创建 一个 类 的 ， 由 <unk> ， 即 实现 了 一个 由 <unk> 的
# golden:在 3.2 版 更改 : 通过 提供 用于 创建 记录 的 工厂 方法 已 使得 " logrecord " 的 创建 更 易于 配置
#
# src:port specific changes: freebsd
# trg:<unk> 特定 的 的 的 更改
# golden:特定 于 freebsd 的 更改 ：
#
# src:<unk> general calendar related functions
# trg:<unk> " <unk> " <unk> " 的 函数
# golden:" calendar " 日历 相关 函数
#
# src:<unk> http protocol client
# trg:<unk> " http . client 协议 客户端 协议 客户端
# golden:" http . client " http 协议 客户端
#
# src:the normal form <unk> <unk> will apply the compatibility <unk> i.e. replace all compatibility characters with their equivalents
# trg:<unk> 将 " <unk> " <unk> " 将 " <unk> " <unk> " <unk> " ， 所有 项 的 所有 项 的 所有
# golden:正规 形式 <unk> （ <unk> ） 将 应用 兼容性 分解 ， <unk> 其 等价 项 替换 所有 兼容性 字符
#
# src:it should yield a mutable sequence object (such as a list)
# trg:<unk> 它 应当 一个 可变 序列 对象 对象 作为 一个 对象
# golden:它 应当 产生 一个 可变 序列 对象 （ 例如 列表 ）
#
# src:return a bytes object which is a printable representation of the character ch
# trg:<unk> 返回 一个 字节 表示 的 的 的 字符 的 的 的
# golden:返回 一个 字节 串 对象 作为 字符 ch 的 可 打印 表示 形式
#
# src:these strings may contain replacement fields, which are expressions delimited by <unk> braces <unk>
# trg:<unk> 这些 字符串 可以 包含 由 圆括号 的 <unk> <unk> <unk>
# golden:这种 字符串 可 包含 替换 字 段 ， <unk> " { } " 标示 的 表达式
#
# src:raise an exception and return " 1" on <unk> return "0" on success
# trg:<unk> 引发 在 " 时 返回 " 1 " 时 返回 " 1 " 时 返回 " null "
# golden:失败 时会 引发 异常 并 返回 " 1 " ； 成功 时 返回 " 0 "
#
# src:create a shared <unk> object and return a proxy for it.
# trg:<unk> 创建 一个 共享 <unk> 的 " queue " 对象 并 返回 它 的 它
# golden:创建 一个 共享 的 " threading . semaphore " 对象 并 返回 它 的 代理
#
# src:what's new in python 2.0
# trg:<unk> python 2.0 有 什么 新 变化
# golden:python 2.0 有 什么 新 变化
#
# src:tk widget <unk> support a document introducing <unk> support for tk
# trg:<unk> tk 控件 " 支持 " <unk> " <unk> 支持 的 支持
# golden:tk <unk> <unk> support 一份 文档 介绍 tk 支持 的 主题
#
# src:note that the global side effect on "sys.stdout" means that this context manager is not suitable for use in library code and most threaded applications
# trg:<unk> 请 注意 ， 该 例程 的 是 上下文 管理器 类型 ， 代码 在 大多数 代码 中 使用 的 代码
# golden:需要 注意 的 点 在于 ， " sys . stdout " 的 全局 副作用 意味着 此 上下文 管理器 不 适合 在 库 代码 和 大多数 多线程 应用程序 中 使用
#
# src:it is simple to write a function that returns a list of the numbers of the fibonacci <unk> instead of printing it:
# trg:<unk> 它 是 简单 的 函数 ， 而 不是 的 而 不是 的 的 而 不是 " 的 " 而 不是 " 的 "
# golden:写 一个 返回 斐波 那契 数列 的 列表 （ 而 不是 把 它 打印 出来 ） 的 函数 ， 非常简单 :
#
# src:the argument may be a floating point number to indicate a more precise sleep time
# trg:<unk> 实参 可以 是 一个 浮点 ， 表示 的 的 的 的 的 秒数
# golden:参数 可以 是 浮点数 ， 以 指示 更 精确 的 <unk> 时间
#
# src:make "\w", "\w", "\b", "\b" and case insensitive matching dependent on the current locale instead of the unicode <unk>
# trg:<unk> 使 " \ n " \ b " \ b " ， 并 不 区分 大小写 而 不 包括 <unk> 的 的
# golden:使 " \ w " 、 " \ w " 、 " \ b " 、 " \ b " 和 大小写 敏感 匹配 依赖于 当前 区域 而 不是 unicode 数据库
#
# src:<unk> is <unk> to 0
# trg:<unk> <unk> 为 0 0 <unk>
# golden:" <unk> _ <unk> " 会 强制 设 为 0
#
# src:<unk> style bytes formatting
# trg:<unk> " <unk> 风格 风格 的 字节 的 的
# golden:" printf " 风格 的 字节 串 格式化
#
# src:an <unk> literal yields a complex number with a real part of <unk>
# trg:<unk> " lc " <unk> 产生 一个 带有 " 的 " ， " 的 " 部分 "
# golden:一个 <unk> 数字 面值 将 生成 一个 <unk> 为 0.0 的 复数
#
# src:the non date components of the datetime are populated with their normal default values
# trg:<unk> 其中 的 的 的 的 的 的 默认值 为 其 默认值 的 默认值
# golden:该 datetime 对象 的 非 日期 部分 将 使用 其 标准 默认值 来 填充
#
# src:resize the stream to the given size in bytes (or the current position if size is not <unk>
# trg:<unk> 对 给定 的 大小 的 大小 的 大小 ， 大小 为 字节 大小 的 位置 0 大小
# golden:将流 的 大小 调整 为 给定 的 size 个 字节 （ 如果 未指定 size 则 调整 至 当前 位置 ）
#
# src:useful when the object is created by a call to an object constructor in the argument list.
# trg:<unk> 当 对象 对象 在 调用 时 调用 对象 时 将 被 调用 对象 时 将 被 转换 为 一个 对象
# golden:当 通过 调用 参数 列表 中 的 对象 构造 器 <unk> 时 很 实用
#
# src:to support <unk> the python api <unk> programmers <unk> defines a set of functions, macros and variables that provide access to most aspects of the python run time system
# trg:<unk> 为了 支持 python python / python / <unk> python ， python ， python ， python 模块 ， python python ， python 程序 的 python 程序 ， python 程序 的 python 程序
# golden:为了 支持 扩展 ， python api （ 应用程序 编程 接口 ） 定义 了 一系列 函数 、 宏 和 变量 ， 可以 访问 python 运行 时 系统 的 大部分 内容
#
# src:(contributed by dong hee na in bpo <unk>
# trg:<unk> （ 由 dong hee na 在 bpo <unk> 中 贡献 。 ）
# golden:（ 由 dong hee na 在 bpo <unk> 中 贡献 。 ）
#
# src:this is the equivalent of the python statement "o1 <unk> o2".
# trg:<unk> 等价 于 python 语句 " o1 " o1 " o1 " o1 "
# golden:等价 于 python 语句 " o1 / / o2 "
#
# src:the default is the mode of fileobj if <unk> otherwise, the default is "'rb'"
# trg:<unk> 默认 为 " none " ， 则 默认值 默认值 默认值 默认值
# golden:如果 可 识别 则 默认 为 fileobj 的 模式 ； 否则 默认 为 " ' rb ' "
#
# src:the file may not be <unk> or <unk>
# trg:<unk> 不 不 <unk> <unk> <unk> 或 <unk> <unk> 或 <unk>
# golden:文件 不能 重命名 或 删除
#
# src:parameters: size an integer or "none"
# trg:<unk> 参数 : 大小 为 整数 整数 或 " none "
# golden:参数 : size 一个 整型 数值 或 " none "
#
# src:to get <unk> style linked lists, you can emulate <unk> <unk> using <unk>
# trg:<unk> 请 改用 ， 你 的 ， 你 可以 使用 " <unk> " <unk> _ <unk> ( ) " , " <unk> _ <unk> ( ) "
# golden:要 获取 <unk> 样式 的 列表 ， 可以 使用 元组 模拟 <unk> 单元 ：
#
# src:new in version 3.8.
# trg:<unk> 3.8 新版 功能 .
# golden:3.8 新版 功能 .
#
# src:(contributed by kyle <unk> in bpo <unk>
# trg:<unk> （ 由 kyle <unk> 在 bpo <unk> 中 贡献 。 ）
# golden:（ 由 kyle stanley 在 bpo <unk> 中 贡献 。 ）
#
# src:make an iterator that filters elements from iterable returning only those for which the predicate is "false"
# trg:<unk> 创建 一个 迭代 器 中 ， 迭代 器 的 元素 ， 迭代 器 的 元素
# golden:创建 一个 迭代 器 ， 只 返回 iterable 中 predicate 为 " false " 的 元素
#
# src:examples of working with "datetime" objects:
# trg:<unk> 使用 " 的 " 的 "
# golden:使用 " datetime " 对象 的 例子 ：
#
# src:one can also suppress the normal shell main module restart
# trg:<unk> 一个 也 可以 在 " 模块 " 模块 中 的 模块
# golden:用户 也 可以 禁用 通常 的 shell 主 模块 重启
#
# src:the initial expression in a list comprehension can be any arbitrary expression, including another list comprehension.
# trg:<unk> 初始 列表 列表 推导 式 可以 可以 任意 任意 任意 ， 列表 列表 列表 列表 列表
# golden:列表 推导 式 中 的 初始 表达式 可以 是 任何 表达式 ， 包括 另 一个 列表 推导 式
#
# src:python defines two types of packages, regular packages and namespace packages
# trg:<unk> python 了 了 两个 和 包 包 包 命名 空间 包
# golden:python 定义 了 两种 类型 的 包 ， 常规 包 和 命名 空间 包
#
# src:the install command ensures that the build commands have been run and then runs the <unk> <unk> , <unk> and <unk> .
# trg:<unk> " 命令 " 命令 解析器 命令 ， 并且 在 命令行 和 <unk> <unk> <unk> 和 <unk> <unk> 和 <unk> <unk>
# golden:install 命令 会 确保 build 命令 已经 运行 ， 然后 运行 子 命令 install _ lib , install _ data 和 install _ scripts
#
# src:allocates n bytes and returns a pointer of type "void " to the allocated memory, or "null" if the request fails.
# trg:<unk> n n 个 字节 字节 返回 分配 指针 分配 给 指针 类型 分配 给 指针 ， 如果 " null " 指针
# golden:分配 n 个 字节 并 返回 一个 指向 分配 的 内存 的 " void " 类型 指针 ， 如果 请求 失败 则 返回 " null "
#
# src:returns the current value of the <unk>
# trg:<unk> 返回 " current " value of value
# golden:返回 <unk> 当前 值
#
# src:<unk> bytecode counter by delta .
# trg:<unk> " <unk> . <unk> " ) " 来 获取
# golden:将 字节 码 计数器 的 值 增加 <unk>
#
# src:when an event <unk> other events for execution, they are scheduled into the future, so they can easily go into the heap
# trg:<unk> 当 事件 事件 循环 ， 事件 循环 ， ， ， ， ， 它们 将 将 它们 将 它们 ， 它们 将 它们 将 将 它们 将 到 到 到 的
# golden:当 一个 事件 将 其他 事件 排入 执行 计划 时 ， 它们 的 调试 时间 向 未来 方向 <unk> ， 这样 它们 可 方便 <unk> 堆
#
# src:this method is called when an unrecognized declaration is read by the parser.
# trg:<unk> 此 方法 会 被 调用 " __ next __ " __ " __ next __ " ) " 方法
# golden:当 解析器 读 到 无法 识别 的 声明 时 ， 此 方法 被 调用
#
# src:they are deprecated in python 3.2 or older
# trg:<unk> 它们 在 python 3.2 或 或 或 或
# golden:这些 函数 自 python 3.2 或 更 <unk> 已 被 弃用
#
# src:changed in version 3.7: start and end are now <unk> to behave like <unk>
# trg:<unk> 在 3.7 版 更改 : 补充 <unk> " <unk> " <unk> " <unk> " <unk> " <unk> " <unk> " <unk> "
# golden:在 3.7 版 更改 : start and end are now <unk> to <unk> like " str [ start : end ] " .
#
# src:the bottom 8 bits are the character <unk> and upper bits are the attributes.
# trg:<unk> 下面 的 <unk> <unk> 字符 字符 和 <unk> ， 与 <unk> ， 与 <unk> <unk>
# golden:下面 的 8 个 比特 <unk> 字符 本身 ， 上面 的 比特 <unk> 为 属性
#
# src:return the current <unk> object, corresponding to the <unk> thread of control
# trg:<unk> 返回 当前 线程 的 对应 于 " <unk> " 对象 的 线程 描述符 对应 的 线程
# golden:返回 当前 对应 调用者 的 控制线 程 的 " thread " 对象
#
# src:if empty, the package <unk> something which is almost equivalent to specifying the date format string <unk> <unk> <unk> <unk>
# trg:<unk> 如果 <unk> ， 则 将 " <unk> " ， " <unk> " 的 " string " 的 格式 字符串
# golden:如果 为空 ， <unk> 将 替换 任何 接近 于 日期 格式 字符串 " ' % y % m % d % h : % m : % s ' " 的 内容
#
# src:avoiding side effects means not using data structures that get updated as a program <unk> every function's output must only depend on its input.
# trg:<unk> 在 " 中 使用 " 数据 ， 数据 的 数据 的 ， ， 它 的 ， 仅 当 只 仅 在 仅 在 仅 在 的 情况 下 ， 仅 在 仅 在 的 情况 下
# golden:消除 副作用 意味着 不能 使用 随 <unk> 而 更新 的 数据结构 ； 每个 函数 的 输出 必须 只 依赖于 输入
#
# src:the "string" module includes a <unk> <unk> class with a simplified syntax suitable for editing by end users
# trg:<unk> " string " 模块 包含 了 一个 " <unk> " 类 的 的 的 类 提供 了 <unk> 的 的 的
# golden:" string " 模块 包含 一个 通用 的 " <unk> " 类 ， 具有 适用 于 <unk> 的 简化 语法
#
# src:used to <unk> <unk> times during a repeated interval
# trg:<unk> 用于 <unk> <unk> <unk> 时间 表示
# golden:用于 在 重复 的 <unk> 中 消除 边界 时间 歧义
#
# src:a dictionary display is a possibly empty series of <unk> pairs enclosed in <unk> <unk>
# trg:<unk> 字典 显示 一个 一个 " <unk> " 的 " <unk> " <unk> " 的 " <unk> "
# golden:字典 显示 是 一个 <unk> 括号 括 起来 的 可能 为空 的 键 / 数据 对 系列 :
#
# src:return successive r length <unk> of elements in the iterable .
# trg:<unk> 返回 以 字节 长度 的 长度 元素 的 元素 数量
# golden:连续 返回 由 iterable 元素 生成 长度 为 r 的 排列
#
# src:create a <unk> object from v , or "null" on failure.
# trg:<unk> 根据 " <unk> " 对象 的 一个 或 ， 或者 " null " ， 返回 " null "
# golden:根据 v 创建 一个 " <unk> " 对象 ， 失败 时 返回 " null "
#
# src:look up the codec for the given encoding and return its "streamreader" class or factory function.
# trg:<unk> 查找 给定 编码 的 编码 的 编码 ， 其 返回 其 函数 或 工厂 函数
# golden:查找 给定 编码 的 编解码器 并 返回 其 " streamreader " 类 或 工厂 函数
#
# src:the default implementation <unk> to <unk> and <unk>
# trg:<unk> 默认 实现 " " " " " " " " " " " " " " " " " " "
# golden:默认 实现 会 <unk> " <unk> ( ) " 和 " <unk> ( ) "
#
# src:these documents are generated from <unk> sources by <unk> a document processor specifically written for the python documentation.
# trg:<unk> 这 从 从 python 中 的 <unk> <unk> <unk> 中 ， python <unk> python 程序 中 的 python
# golden:这些 文档 生成 自 <unk> 原 文档 ， 由 <unk> （ 一个 专门 为 python 文档 写 的 文档 生成器 ） 创建
#
# src:note that the default <unk> method can be overridden in a "tzinfo" subclass to affect the result returned by <unk>
# trg:<unk> 请 注意 默认 默认 " " " " " " ， " " " 子类 ， 子类 ， 子类 ， " 子类 " " " " " " " " 的 " " " " " "
# golden:请 注意 默认 的 " tzinfo . <unk> ( ) " 方法 在 " tzinfo " 的 子类 中 可以 被 重载 ， 从而 影响 " <unk> ( ) " 的 返回 结果
#
# src:<unk> is an optional sequence of file descriptors to keep open between the parent and child
# trg:<unk> maintype 是 一个 可选 的 的 文件 描述符 ， 的 的 的 的 进程
# golden:pass _ fds 是 一个 可选 的 在 <unk> 进程 间 保持 打开 的 文件 描述符 序列
#
# src:this is a measure of the power in an audio <unk>
# trg:<unk> 这是 一个 的 一个 <unk> 的 音频
# golden:测量 音频 信号 的 <unk>
#
# src:the coroutine then has a chance to clean up or even <unk> the request by <unk> the exception with a "try" ... ... "except <unk> ... "finally" block
# trg:<unk> 协程 协程 协程 这个 类 的 " 或 " 的 " ， " 异常 ， 或是 一个 异常 ， 例如 " ... " " " 异常 ， 例如 " ... " ... " " " 异常
# golden:协程 在 之后 有 <unk> 进行 清理 甚至 使用 " try " ... ... " except cancellederror " ... " finally " 代码 块 <unk> 异常 来 <unk>
#
# src:replacing /bin/sh shell command substitution
# trg:<unk> 替代 替代 / bin shell 命令 shell 命令
# golden:替代 / bin / sh shell 命令 替换
#
# src:after all exit handlers have had a chance to run the last exception to be raised is re raised.
# trg:<unk> 在 所有 处理程序 都 都 都 都 将 在 一个 处理程序 都 将 引发 " <unk> "
# golden:在 所有 exit 处理程序 获得 运行 <unk> 之后 ， 所 引发 的 最后 一个 异常 会 被 重新 引发
#
# src:set class that keeps weak references to its elements
# trg:<unk> 设置 创建 类 的 弱 引用 的 构造 器
# golden:保持 对 其 元素 弱 引用 的 集合 类
#
# src:a future is done if it was cancelled or if it has a result or an exception set with <unk> or <unk> calls.
# trg:<unk> 如果 在 被 定义 了 一个 或 或 " 或者 " 或者 " 或者 " 或者 " 或者 " 或者 " " " " " " " " " " " "
# golden:如果 future 为 取消 或 调用 " set _ result ( ) " 设置 了 结果 或 调用 " set _ exception ( ) " 设置 了 异常 ， 那么 它 就是 完成
#
# src:where t is the total number of elements in both sequences, and m is the number of matches, this is 2.0 m / t
# trg:<unk> 其中 的 是 是 的 的 的 的 ， ， ， 的 数字 是 的 的 形式
# golden:其中 t 是 两个 序列 中 元素 的 总 数量 ， m 是 匹配 的 数量 ， 即 2.0 m / t
#
# src:disable the import of the module "site" and the site dependent <unk> of "sys.path" that it <unk>
# trg:<unk> 该 模块 的 的 <unk> 的 <unk> ， <unk> 的 <unk> <unk> <unk> <unk>
# golden:禁用 " site " 的 导入 及其 所 附带 的 基于 <unk> 对 " sys . path " 的 操作
#
# src:font font specifier tuple <unk> size, <unk> name unique font name exists self points to existing named font if true
# trg:<unk> 根据 格式 说明符 （ 元组 （ 如果 name <unk> name 的 ， 名称 ） ， 则 为 " true " ， 如果 它们 将 其 名称
# golden:<unk> 字体 指示 符 元组 ( family , size , <unk> ) name 唯一 的 字体 名 <unk> 指向 现有 命名 字体 （ 如果 有 ）
#
# src:once the file is closed, any operation on the file (e.g. reading or <unk> will raise a "valueerror".
# trg:<unk> 当 文件 文件 文件 文件 文件 文件 文件 的 文件 文件 文件 ， 文件 或 文件 或 " " " " " "
# golden:文件 关闭 后 ， 对 文件 的 任何 操作 （ 例如 读取 或 写入 ） 都 会 引发 " valueerror "
#
# src:it returns the filename of the library file.
# trg:<unk> 它 的 库 的 返回
# golden:返回 库 文件 的 文件名
#
# src:compute the inverse cumulative distribution function, also known as the <unk> function or the <unk> point function
# trg:<unk> 计算 函数 的 的 " ， 也 可以 是 " 函数 " 函数 " 函数 ( ) " 函数 函数 函数 函数 函数 函数 函数 函数 函数
# golden:计算 反向 累积 分布 函数 ， 也 称为 分 位数 函数 或 <unk> 函数
#
# src:using it with arguments for changing the selection was deprecated in python 3.6
# trg:<unk> 使用 它 参数 参数 参数 的 参数 的 的 参数 的 的 参数 的 的
# golden:带 参数 调用 该 方法 来 改变 选择 在 python 3.6 中 已弃 用
#
# src:if the destination is an existing directory, then src is moved inside that directory
# trg:<unk> 如果 目标 为 一个 ， 则 ， 则 " key " ， 则 会 引发 "
# golden:如果 目标 是 已 存在 的 目录 ， 则 src 会 被 移至 该 目录 下
#
# src:return "0" on success or " 1" on failure
# trg:<unk> 成功 时 返回 " 0 " ， 失败 时 返回 " 1 "
# golden:成功 时 返回 " 0 " ， 失败 时 返回 " 1 "
#
# src:most of the examples in this section refer to a turtlescreen instance called <unk>
# trg:<unk> 这个 方法 小节 的 " sys . get _ ) " 方法 的 调用 " 调用 "
# golden:本节 中 的 大部分 示例 都 使用 turtlescreen 类 的 一个 实例 ， 命名 为 " screen "
#
# src:it is not possible to change the encoding or newline if some data has already been read from the stream
# trg:<unk> 如果 可能 无法 在 编码 或 或 的 则 会 被 末尾 则 会 被 取消
# golden:如果 已经 有 数据 从流 中 被 读取 则 将 无法 再 改变 编码 格式 <unk> 结束符
#
# src:<unk> <unk> is a <unk> wrapped binding to the qt toolkit
# trg:<unk> <unk> 是 是 一个 <unk> 的 <unk> <unk> 的 绑定 到 的 的 绑定
# golden:<unk> <unk> 是 一个 针对 qt 工具集 通过 <unk> 包装 的 绑定
#
# src:changed in version 3.5: added support for passing file descriptor to this function.
# trg:<unk> 在 3.5 版 更改 : 添加 了 对 文件 支持 文件 的 支持
# golden:在 3.5 版 更改 : added support for <unk> file <unk> to this function .
#
# src:instead of nested entities it repeats one large entity with a couple of <unk> <unk> over and over again
# trg:<unk> 在 " parser " ， 它 可以 一个 " " " " " ， " ， " <unk> " 和 " <unk> " 的
# golden:它 不是 嵌套 实体 ， 而是 <unk> 又 <unk> 地 重复 一个 具有 <unk> 字符 的 大型 实体
#
# src:returns non zero if the object implements the garbage collector <unk> otherwise returns 0.
# trg:<unk> 如果 对象 返回 " true " 返回 " true " 返回 " true " ； 否则 返回 " true "
# golden:如果 对象 实现 了 垃圾 回收 器 协议 则 返回 非零值 ， 否则 返回 0
#
# src:use <unk> when using pipes to avoid that.
# trg:<unk> 使用 使用 管道 时请 使用 管道 时请 避免
# golden:当 使用 管道 <unk> " popen . communicate ( ) " 来 <unk> 它
#
# src:others of a more general utility are defined here
# trg:<unk> 以下 更 一般 的 定义 的 定义
# golden:其他 更为 通用 的 则 定义 在 这里
#
# src:new in version 3.8.
# trg:<unk> 3.8 新版 功能 .
# golden:3.8 新版 功能 .
#
# src:exchanging objects between processes
# trg:<unk> 在 进程 之间 之间 之间 交换
# golden:在 进程 之间 交换 对象
#
# src:indicates the exponent is larger than <unk> after rounding has occurred
# trg:<unk> <unk> 的 <unk> 是 <unk> 的 后 的 舍入 舍入 舍入 舍入 舍入 舍入 舍入
# golden:表明 在 发生 舍入 之后 的 指数 大于 " <unk> "
#
# src:if denominator is "0", it raises a <unk>
# trg:<unk> 如果 " 为 " ， 则 它 将 引发 " " " "
# golden:如果 denominator 为 " 0 " 将会 引发 " <unk> "
#
# src:either 0 or 1 in the native or standard <unk> representation will be <unk> and any non zero value will be "true" when unpacking.
# trg:<unk> 在 或 或 或 或 或 或 或 " 或 " " " ， " ， 并且 " 任何 非零 任何 值 ， 将 被 任何 被
# golden:<unk> 或 标准 bool 类型 表示 的 0 或 1 将 被 打包 ， 任何 非零值 在 解包 时 将 为 " true "
#
# src:this can be useful for comparison to json inputs during <unk>
# trg:<unk> 这 使得 比较 有用 的 <unk> ， 很 有用 的
# golden:这 在 调试 期间 与 json 输入 进行 比较 时会 很 有用
#
# src:"pprint" data pretty printer
# trg:<unk> " pprint " 数据 美化 输出
# golden:" pprint " 数据 美化 输出
#
# src:"str" is the built in string class
# trg:<unk> " 是 " 内置 的 字符串
# golden:" str " 是 内置 字符串 class
#
# src:<unk> <unk> file handle
# trg:<unk> " <unk> . pth " <unk> "
# golden:<unk> 的 <unk> 文件 句柄
#
# src:all unary arithmetic and bitwise operations have the same <unk>
# trg:<unk> 所有 " 和 " 和 " 运算 ( ) " 和 " 相同 相同 的 签名
# golden:所有 算术 和 位 运算 具有 相同 的 优先级 :
#
# src:the func will be passed to <unk> for each <unk> before its "run()" method is called.
# trg:<unk> func func 将 被 调用 " ( ) " 方法 的 ( ) " 方法 的 调用 " ( ) " 方法 的 方法
# golden:在 每个 线程 的 " run ( ) " 方法 被 调用 前 ， func 会 被 传递 给 " sys . <unk> ( ) "
#
# src:see <unk> for more information.
# trg:<unk> 请参阅 请参阅 多 了解 详情
# golden:查看 " <unk> . < protocol > _ response ( ) " 以 获取 更 多 信息
#
# src:the "try" ... "except" statement has an optional else clause , which, when present, must follow all except clauses
# trg:<unk> " try " 语句 " 语句 " 语句 ， 即使 在 在 在 在 在 在 在 ， 时 ， 即使 的 时候 ， 则 必须 为 " 子句 " 子句
# golden:" try " ... " except " 语句 有 一个 可选 的 else 子句 ， 在 使用 时 必须 放在 所有 的 except 子句 后面
#
# src:optimized <unk> for the case when the other set is much larger than the base set
# trg:<unk> 在 其他 情况 下 ， ， " 设置 " 设置 的 设置 ， 设置 的 设置 的 设置
# golden:当 另 一 集合 <unk> 基础 集合 的 情况 下 优化 了 " <unk> _ update ( ) " 的 性能
#
# src:wrap the <unk> coroutine into a <unk> and <unk> its execution
# trg:<unk> 将 " 协程 . <unk> _ <unk> " ) " , " <unk> " , " <unk> " ) " 和 " 的 "
# golden:将 <unk> 协程 打包 为 一个 " task " 排入 <unk> 准备 执行
#
# src:add a section named section to the instance
# trg:<unk> 将 一个 节 的 节 名称
# golden:向 实例 添加 一个 名为 section 的 节
#
# src:this is useful if you want to match an arbitrary literal string that may have special characters in it
# trg:<unk> 如果 你 想要 的 字符串 ， 字符串 可能 可能 可能 的 的 的 字符 类中
# golden:这 适用 于 当 你 想要 匹配 可能 带有 特殊字符 的 任意 字符串 字 面值 的 情况
#
# src:if you need more control over the formatting of the <unk> provide a <unk> argument to <unk> as in this example:
# trg:<unk> 如果 需要 需要 更多地 控制 的 <unk> ， 请 查看 <unk> 参数 的 " <unk> " <unk> " <unk> " <unk> "
# golden:如果 你 需要 更多地 控制 日期 / 时间 的 格式 ， 请 为 " basicconfig " 提供 <unk> 参数 ， 如下 <unk> 所示 :
#
# src:for example, given the function definition:
# trg:<unk> 例如 ， 给定 函数 :
# golden:例如 ， 对于 以下 函数 定义 :
#
# src:that is determined <unk> by the number of digits in value
# trg:<unk> 以上 是 由 <unk> 的 的 次数
# golden:这 完全 由 value 中 的 位数 决定
#
# src:outputs the record to the file.
# trg:<unk> 输出 记录 的 文件
# golden:将 记录 输出 到 文件
#
# src:new in version 3.1: the <unk> class.
# trg:<unk> 3.1 新版 功能 : <unk> _ <unk> _
# golden:3.1 新版 功能 : " nullhandler " 类
#
# src:objects can contain arbitrary <unk> and <unk> of data
# trg:<unk> 对象 可 包含 任意 的 " <unk> " 和 " <unk> "
# golden:对象 可以 包含 任意 数量 和 类型 的 数据
#
# src:execute the init line provided in the string argument
# trg:<unk> 在 命令行 中 中 的 参数
# golden:执行 在 string 参数 中 提供 的 初始化 行
#
# src:<unk> function has been removed, it was deprecated since python <unk> <unk> <unk> use <unk> instead
# trg:<unk> " pyarg _ function ( ) " 函数 被 被 python ， 它 ， 它 <unk> " py _ <unk> ( ) " , " py _ <unk> ( ) " ) " , " py _ <unk> ( ) " ) "
# golden:" fractions . <unk> ( ) " 函数 已 被 移除 ， 它 自 python 3.5 起 被 弃用 ( bpo <unk> ) ： 请 改用 " math . <unk> ( ) "
#
# src:this copy is <unk> which means that the current background character overwrites the old contents of <unk> .
# trg:<unk> 这 复制 <unk> ， 这 意味着 这 意味着 当前 线程 的 的 内容
# golden:此 复制 是 <unk> 的 ， 这 意味着 当前 背景 字符 会 覆盖 掉 <unk> 的 旧 内容
#
# src:note that leading <unk> in a non zero decimal number are not allowed
# trg:<unk> 注意 注意 ， 非 一个 非 数字 的 非 数字 的 非
# golden:注意 非零 的 十进制 数 开头 不 允许 有 额外 的 零
#
# src:read and return one line from the stream
# trg:<unk> 从流 并 返回 一个 流
# golden:从流 中 读取 并 返回 一行
#
# src:the current namespace is not <unk> for a proper import statement, a subsequent <unk> instruction <unk> the namespace.
# trg:<unk> 当前 命名 空间 不 被 一个 ， ， 一个 一个 一个 ， ， 它 将 在 " <unk> " " " " " " " " " " " "
# golden:当前 命名 空间 不 受 影响 ： 对于 一条 标准 import 语句 ， 会 执行 后续 的 " store _ fast " 指令 来 修改 命名 空间
#
# src:python also includes a data type for sets
# trg:<unk> python 还 可以 包含 一个 数据类型
# golden:python 也 包含 有 集合 类型
#
# src:a enumeration of possible methods the interpreter can use to determine whether a bytecode file is up to date with a source file
# trg:<unk> 使用 " 方法 的 可以 使用 确定 来 确定 缓存 字节 码 的 的 文件 来 缓存 的 文件
# golden:一个 由 可用 方法 组成 的 枚举 ， 解释器 可以 用来 确定 字节 码 文件 是否 与 源文件 保持一致
#
# src:if the class already defines any of <unk> <unk> <unk> or <unk> then "typeerror" is raised.
# trg:<unk> 如果 类 已 定义 了 " " " " " " " " " " " " " " " " " " " " " " " " " "
# golden:如果 类 已经 定义 了 " __ lt __ ( ) " 、 " __ <unk> __ ( ) " 、 " __ gt __ ( ) " 或者 " __ <unk> __ ( ) " 中 的 任意 一个 ， 将 引发 " typeerror "
#
# src:round away from zero.
# trg:<unk> 舍入 的 的 的
# golden:舍入 到 零 的 反 方向
#
# src:if the bytes cannot be <unk> the program immediately tries again after 1 second
# trg:<unk> 如果 字节 字节 串 ， 则 程序 ， 则 可能 ， 则 返回 " 1 "
# golden:如果 字节 数据 无法 被 锁定 ， 程序 会 在 1 秒 之后 立即 <unk>
#
# src:though there is one python implementation which is by far the most <unk> there are some alternate implementations which are of particular interest to different <unk>
# trg:<unk> 注意 ， python 解释器 ， 它 在 大多数 ， 因为 实现 ， 因为 这些 情况 下 ， 因为 这些 是 不同 的 的 的 的 的
# golden:虽然 <unk> python 实现 <unk> 得到 最 广泛 的 <unk> ， 但 也 有 一些 其他 实现 对 特定 <unk> 的 用户 来说 <unk> <unk>
#
# src:<unk> locale's full weekday name
# trg:<unk> " % " % " % b " 的 的
# golden:" % a " 本地化 的 星期 中 <unk> 的 完整 名称
#
# src:in <unk> before <unk> to the "re" module, consider whether your problem can be <unk> with a faster and simpler string method.
# trg:<unk> 在 在 之前 之前 之前 ， ， ， ， ， ， <unk> 前 ， 可以 <unk> <unk> ， 并 使用 的 更 改为
# golden:<unk> ， 在 <unk> " re " 模块 之前 ， 请 考虑 是否 可以 使用 <unk> 更 简单 的 字符串 方法 <unk>
#
# src:changed in version 3.3: if <unk> is "none", then "notimplementederror" is raised.
# trg:<unk> 在 3.3 版 更改 : 如果 " none " ， 则 会 触发 " " " "
# golden:在 3.3 版 更改 : if " sys . implementation . cache _ tag " is " none " , <unk> " notimplementederror " is raised .
#
# src:changed in version 3.7: the size argument is now <unk>
# trg:<unk> 在 3.7 版 更改 : 现在 参数 参数 现在 是 " <unk> .
# golden:在 3.7 版 更改 : size 参数 现在 是 可选 的
#
# src:it's suggested that you use a prefix for the method names, such as <unk> in this example
# trg:<unk> 它 通常 你 使用 " <unk> ( ) " 方法 来 计算 方法 的 的 方式 :
# golden:建议 对 方法 名 使用 前缀 ， 例如 <unk> 中 的 " visit _ "
#
# src:use 4 space <unk> and no <unk>
# trg:<unk> 使用 " <unk> " <unk> " 和 " <unk> . <unk> "
# golden:使用 4 个 空格 缩进 ， 不要 使用 制表符
#
# src:for applications that embed python:
# trg:<unk> 对于 应用程序 的 应用程序 的 工具
# golden:对于 嵌入 python 的 应用程序 ：
#
# src:when most <unk> in "optparse" had either been copy <unk> over or <unk> <unk> it no longer <unk> practical to try to maintain the backwards <unk>
# trg:<unk> 在 大多数 情况 下 ， 在 " 在 ( ) " 或 " set ( ) " 或 " ) " 或 " ) " ， 尝试 不会 尝试 连接 到 的 时候
# golden:当 when <unk> <unk> in " optparse " 中 几乎 所有 内容 都 已 被 <unk> 或 <unk> 上 补丁 时 ， 维持 向下兼容 <unk> 已 是 <unk> 的
#
# src:"strftime()" and "strptime()" format codes
# trg:<unk> " strftime " 和 " 格式 ( ) "
# golden:" strftime ( ) " 和 " strptime ( ) " format <unk>
#
# src:type hint an annotation that specifies the expected type for a variable, a class attribute, or a function parameter or return value.
# trg:<unk> type 通过 一个 类型 ， 的 类型 ， 的 类型 ， 函数 的 一个 一个 函数 或 函数 或 函数 或 函数 或 返回值
# golden:type <unk> 类型 提示 annotation 为 变量 、 类 属性 、 函数 的 形参 或 返回值 指定 预期 的 类型
#
# src:the preamble attribute contains this leading extra <unk> text for mime documents
# trg:<unk> " preamble " 属性 （ 仅 在 mime ） 用于 文本 的 ）
# golden:preamble 属性 包含 mime 文档 开头 部分 的 这些 处于 保护 范围 之外 的 文本
#
# src:return the smallest item in an iterable or the smallest of two or more arguments.
# trg:<unk> 返回 包含 了 两个 或 的 的 或者 ， 或者 返回 两个 的
# golden:返回 可 迭代 对象 中 最小 的 元素 ， 或者 返回 两个 及 以上 实参 中 最小 的
#
# src:implements in place "tos tos1 <unk> tos".
# trg:<unk> " unittest " tos " tos " tos " tos "
# golden:就 地 实现 " tos tos1 / / tos "
#
# src:in the augmented version, "x" is only evaluated once
# trg:<unk> 在 ， 中 的 " <unk> ( 仅 仅
# golden:在 增强 赋值 的 版本 中 ， " x " 仅会 被 求值 一次
#
# src:formats the specified stack information (a string as returned by <unk> but with the last newline <unk> as a string
# trg:<unk> 下面 指定 的 的 的 字符串 ， 字符串 由 字符串 的 字符串 ， 字符串 的 字符串 ， 字符串 的 字符串 的 字符串 的 字符串
# golden:将 指定 的 堆栈 信息 （ 由 " traceback . print _ stack ( ) " 返回 的 字符串 ， 但 移除 末尾 的 换行符 ） 格式化 为 字符串
#
# src:if it is missing or "none" (the default), the arithmetic mean is automatically <unk>
# trg:<unk> 如果 省略 为 " none " ， 则 默认值 ， 则 会 被 自动
# golden:如果 该 参数 省略 或 为 " none " ( 默认值 ) ， 则 会 自动 进行 算术 均值 的 计算
#
# src:changed in version 3.3: argument can be omitted or "none".
# trg:<unk> 在 3.3 版 更改 : 可以 为 " none " 或 " none "
# golden:在 3.3 版 更改 : argument can be <unk> or " none " .
#
# src:changed in version 3.2: <unk> is now "false" by default.
# trg:<unk> 在 3.2 版 更改 : <unk> " 现在 " " " " " "
# golden:在 3.2 版 更改 : <unk> is now " false " by default .
#
# src:<unk> license <unk> for python 2.0
# trg:<unk> " py _ <unk> python <unk> python 2.0
# golden:用于 python 2.0 的 beopen . com 许可 协议
#
# src:"dbm" is a generic interface to variants of the <unk> database <unk> or <unk>
# trg:<unk> " 是 " 一个 " 的 " <unk> " 的 数据库 的 数据库 的 " <unk> "
# golden:" dbm " 是 一种 <unk> 接口 ， 针对 各种 dbm 数据库 包括 " dbm . gnu " 或 " dbm . ndbm "
#
# src:<unk> this returns the real url of the page fetched
# trg:<unk> " <unk> " <unk> ( ) " 返回 返回 " 的 "
# ...
# golden:其余 的 参数 必须 是 在 下面 范围 内 的 整数 ：
#
# src:new in version 3.8.
# trg:<unk> 3.8 新版 功能 .
# golden:3.8 新版 功能 .
#
# src:if the <unk> fails, the original bytes object at bytes is <unk> bytes is set to "null", <unk> is set, and " 1" is returned.
# trg:<unk> 如果 <unk> 了 含有 原始 ， 字节 字节 字节 字节 字节 字节 ， 则 为 " 0 " ， 则 为 " 0 " ， 则 返回 " 0 "
# golden:如果 <unk> 失败 ， 则 bytes 上 的 原 字节 串 对象 将 被 撤销 分配 ， bytes 会 被 设为 " null " ， 同时 设置 " <unk> " 并 返回 " 1 "
#
# src:however, there is nothing in python that tells the interpreter this
# trg:<unk> 但是 ， python 在 python 解释器 中 解释器 的 解释器
# golden:然而 ， python 中 并 没有 告诉 解释器 这 一点
#
# src:new in version 3.5.
# trg:<unk> 3.5 新版 功能 .
# golden:3.5 新版 功能 .
#
# src:the binary and text transforms provided in the standard library are detailed in binary transforms and text <unk>
# trg:<unk> 二进制 和 文本 中 标准 文本 与 标准 库 的 二进制 模式 下 ， 二进制 模式 下 二进制 模式
# golden:the binary and text <unk> <unk> in the standard library are <unk> in 二进制 转换 and 文字 转换 .
#
# src:where "/" and " " are optional
# trg:<unk> " " " " " " " " " " 可选项
# golden:在 这里 " / " 和 " " 是 可选 的
#
# src:an aware object represents a specific <unk> in time that is not open to interpretation
# trg:<unk> 一个 感知 型 对象 的 的 特定 的 时间 ， 时间 ， 不 为 " none "
# golden:感知 型 对象 是 用来 表示 一个 没有 解释 空间 的 固定 时间 点
#
# src:execute the python code in command
# trg:<unk> 在 python 中 的 python 代码
# golden:执行 command 中 的 python 代码
#
# src:protocol family not supported
# trg:<unk> 协议 不 不 支持
# golden:协议 <unk> 不受 支持
#
# src:writing and reading a bzip2 compressed file in binary mode:
# trg:<unk> 编写 和 文件 文件 和 二进制 模式 下 二进制 模式 下 二进制 模式
# golden:用 二进制 模式 写入 和 读取 bzip2 压缩文件 ：
#
# src:lbyl look before you leap
# trg:<unk> 开始 前 ， 你 你
# golden:lbyl “ 先 查看 后 <unk> ” 的 <unk> 缩写
#
# src:return true if p is a dict object or an instance of a subtype of the dict type.
# trg:<unk> 如果 p 是 一个 字典 对象 类型 ， 则 返回 一个 类型 的 实例 类型
# golden:如果 p 是 字典 对象 或者 字典 类型 的 子 类型 的 实例 ， 则 返回 真
#
# src:all the variables below are simply symbolic <unk> into the 10 tuple returned by <unk> <unk> or <unk>
# trg:<unk> 所有 变量 的 所有 参数 都 将 被 <unk> 的 <unk> 所 的 的 的 的 的 的 " <unk> ( ) " , " ) " , " ) "
# golden:以下 所有 变量 是 一些 简单 的 符号 索引 ， 用于 访问 " os . stat ( ) " , " os . <unk> ( ) " 或 " os . <unk> ( ) " 所 返回 的 10 条目 元组
#
# src:better to inherit than <unk>
# trg:<unk> 将 为 " <unk> [ 3 ]
# golden:继承 <unk> 序列化 、 反 序列化
#
# src:package <unk> third party library with expanded time zone and parsing support.
# trg:<unk> 包 <unk> 第三方 与 gzip 兼容 的 iana 时 区 解析 和 解析
# golden:<unk> 包 具有 扩展 时区 和 解析 支持 的 第三方 库
#
# src:the "pass" statement does nothing
# trg:<unk> " pass " 语句 不
# golden:" pass " 语句 什么 也 不 做
#
# src:declares that function should be used as a <unk> function for objects of type type
# trg:<unk> " 函数 " 应当 使用 用作 函数 的 类型 的 函数 对象
# golden:声明 该 function 应当 被 用作 type 类型 对象 的 “ <unk> 函数 ”
#
# src:if no maps are specified, a single empty dictionary is provided so that a new chain always has at least one mapping.
# trg:<unk> 如果 没有 实参 ， 则 一个 空 字典 ， 则 会 将 一个 新 的 一个 新 的 值 ， 则 将 其 值
# golden:如果 没有 <unk> 被 指定 ， 就 提供 一个 默认 的 空 字典 ， 这样 一个 <unk> 至少 有 一个 映射
#
# src:pep 420 implicit namespace packages
# trg:<unk> pep 420 420 420 420 420 420 包
# golden:pep 420 隐式 命名 空间 包
#
# src:another advantage is that strings in python are considered as <unk> as numbers
# trg:<unk> 另 一个 python 是 被 视为 的 形式 公开 形式 公开 形式 公开
# golden:另 一个 优点 是 ， python 中 的 字符串 被 视为 与 数字 一样 “ 基本 ”
#
# src:here is what is <unk>
# trg:<unk> 以下 是 什么 是 :
# golden:<unk> 情况 如下 ：
#
# src:new in version 3.2.
# trg:<unk> 3.2 新版 功能 .
# golden:3.2 新版 功能 .
#
# src:"classvar" does not change python runtime behavior, but it can be used by third party type <unk>
# trg:<unk> " 不 " 不 支持 python ， ， 运行 ， 但 它 可以 通过 使用 第三方 可以 使用 第三方 可以 使用 第三方
# golden:" classvar " 并 不 改变 python 运行 时 行为 ， 但 它 可以 被 用于 第三方 类型 检查 器
#
# src:the "__loader__" attribute must be set to the loader object that the import machinery used when loading the module
# trg:<unk> " 属性 " 必须 为 " 模块 对象 在 加载 器 模块 对象 导入 模块 导入 模块
# golden:" __ loader __ " 属性 必须 被 设为 导入 系统 在 加载 模块 时 使用 的 加载 器 对象
#
# src:the hard coded values <unk> and <unk>
# trg:<unk> " cmd " " 值 " <unk> " 和 " <unk> "
# golden:硬 编码 的 值 " utc " 和 " <unk> "
#
# src:set n to 10 for <unk>
# trg:<unk> 将 n 10 10 10 10
# golden:将 n 设 为 10 以 使用 十分 位
#
# src:plus corresponds to the unary prefix plus operator in python
# trg:<unk> 将 python 2.6 中 的 python 解释器 <unk> 中 的
# golden:对应 于 python 中 的 单 目前 <unk> <unk> 运算符 执行 <unk> 操作
#
# src:under windows, this gives you the native windows error code
# trg:<unk> 在 windows ， 这 windows 你 的 windows 的 的
# golden:在 windows 下 ， 此参数 将 给出 原生 的 windows 错误码
#
# src:you can try to display text with multiple attribute bits set, but curses doesn't guarantee that all the possible <unk> are available, or that they're all <unk> distinct
# trg:<unk> 你 可以 通过 使用 " 来 " 来 计算 来 计算 ， 但 ， 的 的 ， ， 的 的 的 ， ， 这 意味着 的 所有 的 所有 的 的 的 所有
# golden:你 可以 尝试 以 多种 不 属性 位 组合 来 显示 文本 ， 但 curses 不 保证 所有 的 组合 都 是 有效 的 ， 或者 <unk> 有 明显 不同
#
# src:all examples assume a native byte order, size, and alignment with a big endian <unk>
# trg:<unk> 所有 所有 所有 一个 字节 字节 字节 ， 并 将 其 优先级 高于 并 并 将 返回 " " "
# golden:所有 示例 都 假定 使用 <unk> 大 端 机器 的 <unk> 字节 顺序 、 大小 和 对齐 方式
#
# src:the structure has three <unk>
# trg:<unk> 该 具有 有 三种 :
# golden:这个 结构 <unk> 三个 字 段 ：
#
# src:return a <unk> object with an <unk> fixed offset represented by the offset argument.
# trg:<unk> 返回 一个 " datetime . timezone " 对象 的 " datetime " ， 它 通过 " <unk> " 对象 的
# golden:返回 一个 " datetime . timezone " 对象 ， 该 对象 具有 以 offset 参数 表示 的 <unk> 固定 时差
#
# src:<unk> <unk> <unk> go to <unk> of file
# trg:<unk> " <unk> " <unk> " <unk> " 的 文件 的 文件
# golden:" c home " / " c end " 跳转 到 文档 <unk> / <unk>
#
# src:<unk> is an up and <unk> compiler of python into c++ code, <unk> to support the full python language
# trg:<unk> <unk> python python 和 python python python 的 python ， python python python python python <unk> python python 的 python 版本
# golden:<unk> 是 一个 将 python <unk> c++ 代码 的 <unk> 编译器 ， 旨在 支持 完整 的 python 语言
#
# src:the <unk> exception can be raised in your extension module using a call to <unk> as shown <unk>
# trg:<unk> " <unk> " 在 " " 中 使用 " 模块 " 模块 的 " ， " 模块 " 模块 " " " . " " " " " " " " " " " ) " 来 "
# golden:" spam . error " 异常 可以 在 扩展 模块 中 抛出 ， 通过 " pyerr _ <unk> ( ) " 函数调用 ， 如下 ：
#
# src:this method, and others that <unk> call this method, raises an auditing event <unk> with argument <unk>
# trg:<unk> 此 方法 和 调用 " . <unk> ( ) " 调用 调用 此 方法 会 引发 " " " " " " " " "
# golden:引发 一个 审计 事件 " ctypes . <unk> " ， 附带 参数 " address "
#
# src:this is a class for comparing sequences of lines of text, and producing human readable differences or <unk>
# trg:<unk> 这是 一个 序列 的 序列 的 的 的 ， 并且 可读 的 的 或 最大值 的 或 最大值 的 或 最大值
# golden:这个 类 的 作用 是 比较 由 文本 行 组成 的 序列 ， 并 产生 <unk> 人 阅读 的 差异 或 增量 信息
#
# src:to help <unk> modules and provide a naming <unk> python has a concept of packages .
# trg:<unk> 帮助 帮助 信息 ， 模块 ， " " " " python " ， 一个 python 的 一个
# golden:为了 帮助 组织 模块 并 提供 名称 层次结构 ， python 还 引入 了 包 的 概念
#
# src:thus, calling <unk> with keyword arguments would lead to an error:
# trg:<unk> " " " " " " " " " 参数 ， 参数 参数 参数 " key "
# golden:因此 ， 附带 关键字 参数 调用 " divmod ( ) " 将会 导致 报错 :
#
# src:however, in some cases it is <unk> to force a type to be formatted as a string, overriding its own definition of formatting
# trg:<unk> 然而 ， 有些 某些 情况 下 ， 它 将 其 转换 为 一个 中将 <unk> ， 它 的 其 作为 其 的 的
# golden:但是 ， 在 某些 情况 下 最好 强制 将 类型 格式化 为 一个 字符串 ， 覆盖 其 本身 的 格式化 定义
#
# src:the first occurrence of a <unk> substring on a line is considered a delimiter
# trg:<unk> 在 <unk> 的 <unk> <unk> 的 一个 字符
# golden:在 一行 中 首次 出现 的 分隔 子 字符串 会 被 视为 一个 分隔符
#
# src:changed in version 3.5: added the two tuple form for the address constructor parameter.
# trg:<unk> 在 3.5 版 更改 : 添加 了 元组 " <unk> " 的 构造 器
# golden:在 3.5 版 更改 : added the <unk> tuple form for the address constructor parameter .
#
# src:changed in version 3.9: the errors parameter was added.
# trg:<unk> 在 3.9 版 更改 : 增加 了 errors 形参
# golden:在 3.9 版 更改 : 增加 了 errors 形参
#
# src:note also that updating <unk> will render this dictionary <unk>
# trg:<unk> 请 注意 ， " <unk> . pth " ) " 将 字典 字典
# golden:还要 注意 更新 " os . <unk> " 将 导致 此 字典 失效
#
# src:the default <unk> when not otherwise specified can be configured at compile time.
# trg:<unk> 默认 不 不 不 在 不 指定 的 时候 ， 可以 在 " <unk> " 时
# golden:默认 的 " <unk> " 未 通过 其他 方式 指定 时 可 在 编译 时 进行 配置
#
# src:if <unk> is false and <unk> is true, each tab character will be replaced by a single space, which is not the same as tab <unk>
# trg:<unk> 如果 " 为 假值 " ， " false " ， 则 会 被 视为 空白 ， 并且 将 被 一个 " 相同 的 "
# golden:如果 " <unk> _ <unk> " 为 假值 且 " replace _ <unk> " 为 真值 ， 每个 制表符 将 被 替换 为 单个 空格 ， 这 与 制表符 扩展 是 不 一样 的
#
# src:there are also bindings to <unk>
# trg:<unk> 还 也 有 绑定 到 绑定
# golden:此外 也 有 对 <unk> 的 绑定
#
# src:status code returned by <unk>
# trg:<unk> " code . <unk> ( ) " 返回 的 返回
# golden:由 <unk> 的 状态 码
#
# src:the input source can be given as a string, a file like object, or an <unk> object; parsers will use this function to implement the <unk> source argument to their "parse()" method.
# trg:<unk> 输入 可以 可以 给定 一个 一个 " 类 的 一个 文件 对象 ， 或者 ， 或者 ， " ， " ， " ， " 方法 的 参数 ， 该 方法 的 参数
# golden:输入 源 的 给出 形式 可以 为 字符串 、 文件 类 对象 或 " <unk> " 对象 ； 解析器 将 使用 此 函数 来 针对 它们 的 " parse ( ) " 方法 实现 <unk> source 参数
#
# src:two common operations on an <unk> output are 1) performing some operation for every element, <unk> selecting a subset of elements that meet some condition
# trg:<unk> 两个 常见 的 常见 操作 操作 的 输出 是 ， 输出 是 ， 的 的 的 ， 而 不是 的 的 的 的 一个 ， 的 的 的 一个
# golden:迭代 器 的 输出 有 两个 很 常见 的 使用 方式 ， 1 ) 对 每 一个 元素 执行 操作 ， 2 ) 选择 一个 <unk> 的 元素 子集
#
# src:<unk> call <unk> <unk> <unk> <unk>
# trg:<unk> <unk> 调用 调用 : 调用 调用 调用 调用 " <unk> ( func , func , func , func ,
# golden:<unk> call <unk> ( <unk> ) 过滤器 ： " filter _ <unk> "
#
# src:the module defines the following functions:
# trg:<unk> 这个 模块 定义 了 以下 函数 ：
# golden:这个 模块 定义 了 以下 函数 ：
#
# src:some way of <unk> <unk> <unk> would be <unk> the <unk> variable is not <unk>
# trg:<unk> 某些 <unk> 的 <unk> <unk> <unk> <unk> 的 <unk> <unk> 的 <unk>
# golden:一些 可靠 地 检测 <unk> 的 方法 会 很 好 ； 仅 检查 " <unk> " 变量 是 不够 的
#
# src:<unk> is also a context manager and therefore supports the "with" statement
# trg:<unk> " <unk> " 是 " 上下文 管理器 是 管理器 支持 " with " 语句
# golden:" iobase " 也 是 一个 上下文 管理器 ， 因此 支持 " with " 语句
#
# src:return the negation of the argument
# trg:<unk> 返回 参数 的 参数
# golden:回到 参数 的 <unk>
#
# src:"random" generate pseudo random numbers
# trg:<unk> " random " 生成 伪 随机数
# golden:" random " 生成 伪 随机数
#
# src:return a new instance method object, with func being any callable object func is the function that will be called when the instance method is called.
# trg:<unk> 当 一个 新 的 对象 对象 ， 对象 调用 对象 func 调用 对象 调用 对象 调用 对象 调用 对象 调用 对象 调用 调用 对象 调用 调用 对象 调用 调用 对象 调用 调用 对象
# golden:返回 一个 新 的 实例 方法 对象 ， func 应为 任意 可 调用 对象 ， func 将 在 实例 方法 被 调用 时 作为 函数 被 调用
#
# src:new in version 3.7.
# trg:<unk> 3.7 新版 功能 .
# golden:3.7 新版 功能 .
#
# src:<unk> : "true" if the clock can be changed automatically (e.g. by a <unk> <unk> or manually by the system <unk> "false" otherwise
# trg:<unk> " : 如果 " true " ， 则 可以 通过 " <unk> " ， " <unk> " ， " <unk> " <unk> " 返回 " false "
# golden:<unk> ： 如果 时钟 可以 自动 更改 （ 例如 通过 <unk> <unk> 程序 ） 或 由 <unk> 手动 更改 ， 则 为 " true " ， 否则 为 " false "
#
# src:if it is a string, the string is parsed as a suite of python statements which is then executed (unless a syntax error <unk>
# trg:<unk> 如果 是 是 一个 字符串 字符串 ， 则 会 被 认为 的 python 语句 ， 它 的 执行 它 的 语法 的 语法
# golden:如果 是 字符串 ， 那么 该 字符串 将 被 解析 为 一系列 python 语句 并 执行 （ 除非 发生 语法错误 ）
#
# src:the instance will be used as global state for the functions of this module, and is also returned to use during iteration
# trg:<unk> 实例 实例 将 使用 该 模块 的 函数 的 的 ， 并且 使用 的 使用 ， 因此 使用 使用 使用 使用 使用 使用 的 使用
# golden:该 实例 将 被 用作 此 模块 中 函数 的 全局 状态 ， 并且 还 将 在 迭代 期间 被 返回 使用
#
# src:this method is useful for finding rational <unk> to a given floating point <unk>
# trg:<unk> 这个 方法 适用 于 " <unk> 浮点数 的 浮点数 浮点数
# golden:此 方法 适用 于 找出 给定 浮点数 的 <unk> 近似值 ：
#
# src:packs a fixed length string, s
# trg:<unk> 打包 一个 长度 为 " 字符串 "
# golden:打包 固定 长度 字符串 s
#
# src:using those functions, the above examples become simpler and <unk>
# trg:<unk> 使用 " ' " ' " ' " ' " 和 " <unk> "
# golden:使用 这些 函数 ， 上述 示例 变得 更 简单 ， 更 <unk> ：
#
# src:unless explicitly <unk> these functions support "int", "float", "decimal" and "fraction"
# trg:<unk> " 显式 " " " 这些 函数 支持 和 " " " " " 和 " 和 "
# golden:除非 明确 注释 ， 这些 函数 支持 " int " ， " float " ， " decimal " 和 " fraction "
#
# src:the argument to <unk> is wrapped in calls to "open()", <unk> and <unk>
# trg:<unk> 参数 缩写 为 " null " ， " 在 " sys . set _ args ( ) " , " " " " " " " "
# golden:" <unk> ( ) " 的 <unk> 参会 使用 " open ( ) " ， " compile ( ) " 和 " exec ( ) " 包装
#
# src:macros to extract fields from time delta objects
# trg:<unk> 一些 用来 从 time time 对象 的 宏 对象
# golden:一些 用来 从 timedelta 对象 中 提取 字段 的 宏
#
# src:for loggers other than the root <unk> some additional information is required
# trg:<unk> 对于 ， 其他 日志 的 " ， " 一些 附加 的 信息
# golden:对于 根 日志 记录器 以外 的 日志 记录器 ， 还 需要 某些 附加 信息
#
# src:the default message can be overridden with the <unk> " keyword argument:
# trg:<unk> 默认 消息 " " " " " " " " " " " " " " " " " " " " "
# golden:可以 通过 " usage " 关键字 参数 覆盖 这一 默认 消息 ：
#
# src:some semantics have changed since the writing of this document (e.g. redirecting based on "none" in <unk>
# trg:<unk> 有些 在 有 一些 的 " 的 " " " 中 " 的 " " " " " " " " " " " " " 的 "
# golden:<unk> 编写 这个 文档 开始 ， 一些 语义 已经 发生 改变 了 （ 比如 基于 " sys . modules " 中 " none " 的 重定向 ）
#
# src:constructor for a "streamwriter" instance.
# trg:<unk> " 一个 " 实例 的 实例
# golden:" streamwriter " 实例 的 构造 器
#
# src:sequence of operation names, <unk> using the <unk>
# trg:<unk> 操作 ， <unk> 使用 " <unk> _ <unk> ( ) "
# golden:操作 名称 的 序列 ， 可 使用 字节 <unk> 索引
#
# src:if you're trying to build a pathname for a <unk> command, try e.g. one of
# trg:<unk> 如果 你 尝试 为 一个 一个 " ， " ， 则 ， 则 " 一个 " 例如 " 的 一个 一个
# golden:如果 您 正在 尝试 为 <unk> 命令 构建 路径名 ， 请 尝试 以下 示例
#
# src:see also the <unk> method <unk>
# trg:<unk> 另 请 " <unk> ( ) " 方法 ( ) " 方法
# golden:另 参见 <unk> / turtle 方法 " <unk> ( ) "
#
# src:added <unk> and its variants
# trg:<unk> 添加 了 " <unk> _ 和 ( ) " 和 " 的 _ <unk> _
# golden:添加 了 " <unk> ( ) " 及其 变化 形式
#
# src:if you have associated levels with names using <unk> then the name you have associated with level is returned
# trg:<unk> 如果 你 用 的 名称 使用 名称 ， 名称 ， 名称 名称 名称 你 你 的 名称 你 的 名称
# golden:如果 你 使用 " <unk> ( ) " 将 级别 关联 到 名称 则 会 返回 你 为 level 所 关联 的 名称
#
# src:"copy" shallow and deep copy operations
# trg:<unk> " copy " 浅层 深层 深层 深层 复制 操作
# golden:" copy " 浅层 ( shallow ) 和 深层 ( deep ) 复制 操作
#
# src:after "f <unk> the call "f(b)" returns <unk>
# trg:<unk> 在 " <unk> ( ) " 之后 调用 " 调用 " ( ) " 返回 "
# golden:在 " f <unk> ( ' name ' ) " 之后 ， 调用 " f ( b ) " 将 返回 " b . name "
#
# src:return "true" if the "tarinfo" object is a regular file.
# trg:<unk> 如果 object 是 一个 " true " 则 返回 " true "
# golden:如果 " tarinfo " 对象 为 普通 文件 则 返回 " true "
#
# src:if compact is false (the default) each item of a long sequence will be formatted on a separate line
# trg:<unk> 如果 <unk> 为 假值 ， 为 " （ 默认值 ） ， 则 将 将 在 将 被 转换 为 一行
# golden:如果 <unk> 为 假值 （ 默认 ） 则 长 序列 的 <unk> 将 被 格式化 为 单独 的 行
#
# src:if the optional argument header is present and true, underscore will be decoded as space
# trg:<unk> 如果 可 选 参数 header 参数 ， 则 为 " none " ， 则 将 被 视为 为 "
# golden:如果 提供 了 可选 参数 header 且 为 真值 ， 下划线 将 被 解码 为 空格
#
# src:new in version 3.2.
# trg:<unk> 3.2 新版 功能 .
# golden:3.2 新版 功能 .
#
# src:owner has read <unk>
# trg:<unk> " 具有 " 的 只读
# golden:所有者 具有 读取 权限
#
# src:return a dictionary of the builtins in the current execution frame, or the interpreter of the thread state if no frame is currently executing.
# trg:<unk> 返回 当前 帧 中 的 当前 帧 中 ， 如果 当前 帧 的 " ， " " " " "
# golden:返回 当前 执行 帧 中 内置 函数 的 字典 ， 如果 当前 没有 帧 正在 执行 ， 则 返回 线程 状态 的 解释器
#
# src:many editors and ides provide syntax <unk> debugging tools, and pep 8 <unk>
# trg:<unk> 许多 、 和 分发 和 语法 和 语法 和 语法 和 和 pep <unk> 和 pep <unk> 和 pep <unk>
# golden:大多数 编辑器 和 集成 开发 环境 支持 语法 <unk> ， 调试 工具 和 pep 8 检查
#
# src:the cython and <unk> libraries offer <unk> over python's c api
# trg:<unk> " 和 " <unk> " <unk> " <unk> " python 的 c api
# golden:cython 和 <unk> 库 提供 了 对于 python 的 c api 的 抽象
#
# src:for integer and pointer types, it is an integer, for character types, it is a single character bytes object or string, for character pointer types it is a python bytes object or string.
# trg:<unk> 对于 整数 和 指针 ， 对于 整数 ， 对于 整数 代表 一个 字符 ， bytes like object 或 bytes like object 或 字节 串 对象
# golden:对于 整数 和 指针 类型 ， 它 是 一个 整数 ， 对于 字符 类型 ， 它 是 一个 单 字符 字符串 对象 或 字符串 ， 对于 字符 指针 类型 ， 它 是 一个 python 字节 串 对象 或 字符串
#
# 0.0760201715402007
